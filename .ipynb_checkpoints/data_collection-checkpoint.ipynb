# %% [markdown]
# <h1 align = "center">GEAR Network</h1>
# <h4 align = "center">Jiarui Xu - jxu57@illinois.edu</h4>

# %%
# %matplotlib inline

# %%
import scrapy
import requests
import urllib2
import BeautifulSoup
import pickle
import pyprind
import json
import collections
import matplotlib.pyplot as plt

# %%
import mathscinet

# %% [markdown]
# # Load basic infomation

# %%
with open("./source_files/original_profile.json") as f:
    orig_profile = json.load(f)

# %%
with open("./source_files/mathsci.json") as f:
    math_profile = json.load(f)

# %%
mapper = {}

for person in math_profile['items']:
    member_id = person['member_id']
    mathsci_id = person['mathsci_id']
    mapper[member_id-1] = mathsci_id

# %%
for person in orig_profile['items']:
    try:
        person['mathsci_id'] = mapper[person['member_id']]
    except:
        person['mathsci_id'] = 0;
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-fadfc622f0a6> in <module>()
#       1 for person in orig_profile['items']:
# ----> 2     person['mathsci_id'] = mapper[person['member_id']]
#
# KeyError: 368

# %%
math_profile
# Out:
# {u'groups': [{u'slug': u'member', u'title': u'GEAR Members'},
#   {u'slug': u'graduate', u'title': u'Graduate Students'},
#   {u'slug': u'postdoc', u'title': u'Postdocs'}],
#  u'items': [{u'mathsci_id': u'MR671767',
#    u'member_id': 1,
#    u'member_type': u'member',
#    u'name': u'Ian',
#    u'organization': u'University of California, Berkeley',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Agol',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR604180',
#    u'member_id': 2,
#    u'member_type': u'member',
#    u'name': u'J\xf8rgen',
#    u'organization': u'Aarhus University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Andersen',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR663249',
#    u'member_id': 3,
#    u'member_type': u'member',
#    u'name': u'Jayadev',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'Jon Chaika',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces',
#    u'short_bio': u'Dynamics on moduli spaces of quadratic differentials, comparisons to dynamics on moduli spaces of lattices.',
#    u'surname': u'Athreya',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.illinois.edu/~jathreya'},
#   {u'mathsci_id': u'MR912405',
#    u'member_id': 4,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'University of Adelaide',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Baraglia',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR290166',
#    u'member_id': 5,
#    u'member_type': u'member',
#    u'name': u'Ara',
#    u'organization': u'City University of New York',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Basmajian',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR627760',
#    u'member_id': 6,
#    u'member_type': u'member',
#    u'name': u'Mikhail',
#    u'organization': u'Instituto Nacional de Mathematica Pura e Aplicada',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Belolipetsky',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR213892',
#    u'member_id': 7,
#    u'member_type': u'member',
#    u'name': u'Yves',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Benoist',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR312126',
#    u'member_id': 8,
#    u'member_type': u'member',
#    u'name': u'Olivier',
#    u'organization': u'\xc9cole Normale Sup\xe9rieure',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Biquard',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR312802',
#    u'member_id': 9,
#    u'member_type': u'member',
#    u'name': u'Hans',
#    u'organization': u'McMaster University',
#    u'other_collaborators': u'Cynthia Curtis, Stefan Friedl, Eric Harper, Christopher Herald, Benjamin Himpel, Paul Kirk, Andrew Nicas,',
#    u'photo': u'BodenHans.jpg',
#    u'research_interests': u'Gauge theory and low dimensional topology',
#    u'short_bio': u'Gauge theory and low dimensional topology, moduli spaces of flat connections and character varieties. Applications to invariants of knots and 3-manifolds.',
#    u'surname': u'Boden',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.mcmaster.ca/boden'},
#   {u'mathsci_id': u'MR38785',
#    u'member_id': 10,
#    u'member_type': u'member',
#    u'name': u'Michel',
#    u'organization': u'Universit\xe9 de Toulouse',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Boileau',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR39080',
#    u'member_id': 11,
#    u'member_type': u'member',
#    u'name': u'Francis',
#    u'organization': u'University of Southern California',
#    u'other_collaborators': u'Qingtao Chen, Helen Wong',
#    u'photo': u'BonahonFrancis.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Geometric Group Theory',
#    u'short_bio': u'With respect to GEAR, the main thrust of my research is 2-fold. The first one is higher Teichm\xfcller theory and representations of surface groups in SL_n(R) or SL_n(C). I am also interested in developing connections between 3-dimensional hyperbolic geometry, representations of surface groups in SL_2(C), and knot invariants based on the quantum group U_q(sl_2).',
#    u'surname': u'Bonahon',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-bcf.usc.edu/~fbonahon/'},
#   {u'mathsci_id': u'MR219677',
#    u'member_id': 12,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'Universit\xe9 du Qu\xe9bec \xe0 Montr\xe9al',
#    u'other_collaborators': u'Adam Clay, Dale Rolfsen, Cameron Gordon, Liam Watson, Shicheng Wang, Radu Cebanu, Genevieve Walsh, Stephan Tillmann',
#    u'photo': u'',
#    u'research_interests': u'Low dimensional topology and geometry. Character varieties.',
#    u'short_bio': u'Low dimensional topology and geometry. Character varieties and their applications to low-dimensional manifolds.',
#    u'surname': u'Boyer',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.cirget.uqam.ca/boyer/boyer.html'},
#   {u'mathsci_id': u'MR304864',
#    u'member_id': 13,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'Indranil Biswas, Jim Glazebrook, Tomas Gomez, Adam Jacob, Franz Kamber, Vincent Mercat, Vicente Munoz, Peter Newstead, Mathias Stemmler',
#    u'photo': u'BradlowSteven.jpg',
#    u'research_interests': u'Higgs Bundles',
#    u'short_bio': u"I'm interested in moduli spaces associated with holomorphic vector bundles. In particular, I'm a big fan of applications of Higgs bundle technology to the study of surface group representation varieties. Before I die, I'd like to be able to compute the surface group representation corresponding to any given Higgs bundle, and vice versa.",
#    u'surname': u'Bradlow',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR360507',
#    u'member_id': 14,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Boston College',
#    u'other_collaborators': u'Edward Taylor, Petra Bonfert-Taylor',
#    u'photo': u'BridgemanMartin.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'My current research interests are convex hulls of Kleinian groups, geometric identities on Moduli spaces and generalizations of Weil-Petersson geometry to higher Teichm\xfcller spaces. ',
#    u'surname': u'Bridgeman',
#    u'title': u'GEAR Member',
#    u'website': u'https://www2.bc.edu/~bridgem/'},
#   {u'mathsci_id': u'MR671629',
#    u'member_id': 15,
#    u'member_type': u'member',
#    u'name': u'Lewis',
#    u'organization': u'University of Texas at Austin',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bowen',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR328097',
#    u'member_id': 16,
#    u'member_type': u'member',
#    u'name': u'Jeffrey',
#    u'organization': u'Brown University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Brock',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR687266',
#    u'member_id': 17,
#    u'member_type': u'member',
#    u'name': u'Kenneth',
#    u'organization': u'University of Utah',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bromberg',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR675963',
#    u'member_id': 18,
#    u'member_type': u'member',
#    u'name': u'Michelle',
#    u'organization': u'Universit\xe9 de Gen\xe8ve',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bucher',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR215170',
#    u'member_id': 19,
#    u'member_type': u'member',
#    u'name': u'Marc',
#    u'organization': u'Eidgen\xf6ssische Technische Hochschule Z\xfcrich',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Burger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR605373',
#    u'member_id': 20,
#    u'member_type': u'member',
#    u'name': u'Danny',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Calegari',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR248015',
#    u'member_id': 21,
#    u'member_type': u'member',
#    u'name': u'Richard',
#    u'organization': u'University of Michigan',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Canary',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR670970',
#    u'member_id': 22,
#    u'member_type': u'member',
#    u'name': u'Virginie',
#    u'organization': u'Universit\xe9 de Sherbrooke',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Charette',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR239760',
#    u'member_id': 23,
#    u'member_type': u'member',
#    u'name': u'Daryl',
#    u'organization': u'University of California, Santa Barbara',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cooper',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR53270',
#    u'member_id': 24,
#    u'member_type': u'member',
#    u'name': u'Marc',
#    u'organization': u'University of Illinois at Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Culler',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR313609',
#    u'member_id': 25,
#    u'member_type': u'member',
#    u'name': u'Georgios',
#    u'organization': u'Brown University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Daskalopoulos',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR815548',
#    u'member_id': 26,
#    u'member_type': u'member',
#    u'name': u'Kelly',
#    u'organization': u'Buffalo State College',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Delp',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR740008',
#    u'member_id': 27,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Deraux',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR291438',
#    u'member_id': 28,
#    u'member_type': u'member',
#    u'name': u'Todd',
#    u'organization': u'Howard University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Drumm',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR822577',
#    u'member_id': 29,
#    u'member_type': u'member',
#    u'name': u'Moon',
#    u'organization': u'Tufts University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Duchin',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR796273',
#    u'member_id': 30,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'University of Illinois at Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dumas',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR658371',
#    u'member_id': 31,
#    u'member_type': u'member',
#    u'name': u'Sorin',
#    u'organization': u'Universit\xe9 de Nice Sophia-Antipolis',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dumitrescu',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR341957',
#    u'member_id': 32,
#    u'member_type': u'member',
#    u'name': u'Nathan',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dunfield',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR253227',
#    u'member_id': 33,
#    u'member_type': u'member',
#    u'name': u'Alex',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'Artur Avila, Jon Chaika, Maxim Kontsevich, Carlos Matheus Santos, Martin M\xf6ller, Marcelo Viana, Anton Zorich',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory',
#    u'short_bio': u'',
#    u'surname': u'Eskin',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.uchicago.edu/~eskin'},
#   {u'mathsci_id': u'MR321364',
#    u'member_id': 34,
#    u'member_type': u'member',
#    u'name': u'Elisha',
#    u'organization': u'Universit\xe9 Pierre et Marie Curie - Paris VI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Falbel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR329207',
#    u'member_id': 35,
#    u'member_type': u'member',
#    u'name': u'Benson',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Farb',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR717335',
#    u'member_id': 36,
#    u'member_type': u'member',
#    u'name': u'Roberto',
#    u'organization': u'Universit\xe0 di Pisa',
#    u'other_collaborators': u'Riccardo Benedetti, Bruno Martelli, Cristina Pagliantini, Carlo Petronio, Alessandro Sisto',
#    u'photo': u'FrigerioRoberto.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Bounded cohomology and simplicial volume.',
#    u'short_bio': u'I am currently working on bounded cohomology of discrete groups, with a particular attention to results and techniques related to geometric group theory. I also used to study classical hyperbolic geometry, mainly in dimension 3, and I am still interested in the geometry and topology of low-dimensional manifolds.',
#    u'surname': u'Frigerio',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.dm.unipi.it/~frigerio/'},
#   {u'mathsci_id': u'MR690516',
#    u'member_id': 37,
#    u'member_type': u'member',
#    u'name': u'Carlos',
#    u'organization': u'Universidade T\xe9cnica de Lisboa',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Florentino',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR277295',
#    u'member_id': 38,
#    u'member_type': u'member',
#    u'name': u'Vladimir',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Fock',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR308447',
#    u'member_id': 39,
#    u'member_type': u'member',
#    u'name': u'Giovanni',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Forni',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR70100',
#    u'member_id': 40,
#    u'member_type': u'member',
#    u'name': u'Louis',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'Mapping class groups',
#    u'surname': u'Funar',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-fourier.ujf-grenoble.fr/~funar/'},
#   {u'mathsci_id': u'MR671567',
#    u'member_id': 41,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'Temple University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Futer',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR195365',
#    u'member_id': 42,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'Princeton University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gabai',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR948082',
#    u'member_id': 43,
#    u'member_type': u'member',
#    u'name': u'Vaibhav',
#    u'organization': u'University of Warwick',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gadre',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR341742',
#    u'member_id': 44,
#    u'member_type': u'member',
#    u'name': u'Oscar',
#    u'organization': u'Consejo Superior de Investigaciones Cient\xedficas',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Garc\xeda-Prada',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR190609',
#    u'member_id': 45,
#    u'member_type': u'member',
#    u'name': u'Jane',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gilman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR673281',
#    u'member_id': 46,
#    u'member_type': u'member',
#    u'name': u'Yair',
#    u'organization': u'Ben-Gurion University of the Negev',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Glasner',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR74725',
#    u'member_id': 47,
#    u'member_type': u'member',
#    u'name': u'William',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Goldman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR229715',
#    u'member_id': 48,
#    u'member_type': u'member',
#    u'name': u'Alexander',
#    u'organization': u'Yale University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Goncharov',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR1100669',
#    u'member_id': 49,
#    u'member_type': u'member',
#    u'name': u'Matthias',
#    u'organization': u'Pixar Animation Studios',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'G\xf6rner',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR355366',
#    u'member_id': 50,
#    u'member_type': u'member',
#    u'name': u'Peter',
#    u'organization': u'Universidade do Porto',
#    u'other_collaborators': u'I. Biswas, S.B.S.D. Castro, S. Dakhlia, A.D. King, M. Logares, V. Mu\xf1oz',
#    u'photo': u'GothenPeter.jpg',
#    u'research_interests': [u'Higgs bundles'],
#    u'short_bio': u'Geometry and topology of moduli spaces. Higgs bundles and their application to the study of character varieties of surface groups, especially for real Lie groups.',
#    u'surname': u'Gothen',
#    u'title': u'GEAR Member',
#    u'website': u'http://cmup.fc.up.pt/cmup/pbgothen/'},
#   {u'mathsci_id': u'MR757489',
#    u'member_id': 51,
#    u'member_type': u'member',
#    u'name': u'Marco',
#    u'organization': u'University of Toronto',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gualtieri',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR743876',
#    u'member_id': 52,
#    u'member_type': u'member',
#    u'name': u'Olivier',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u'',
#    u'photo': u'GuichardOlivier.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Main interests are convex-cocompact subgroups and generalizations, the relations between geometric and dynamical properties for discrete subgroups of Lie groups with an emphasis on "Higher Teichm\xfcller spaces".',
#    u'surname': u'Guichard',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-irma.u-strasbg.fr/~guichard/'},
#   {u'mathsci_id': u'MR1073989',
#    u'member_id': 53,
#    u'member_type': u'member',
#    u'name': u'Rosemary',
#    u'organization': u'University of Iowa',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Guzman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR905915',
#    u'member_id': 54,
#    u'member_type': u'member',
#    u'name': u'Thomas',
#    u'organization': u'Universit\xe9 Montpellier II',
#    u'other_collaborators': u'Dawid Kielak, Petra Schwer',
#    u'photo': u'HaettelThomas.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am mainly interested in the asymptotic geometry of symmetric spaces, in degeneration of geometric structures and in the geometry of braid groups.',
#    u'surname': u'Haettel',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.univ-montp2.fr/~haettel'},
#   {u'mathsci_id': u'MR333845',
#    u'member_id': 55,
#    u'member_type': u'member',
#    u'name': u'Tam\xe1s',
#    u'organization': u'Ecole Polytechnique F\xe9d\xe9rale de Lausanne',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Hausel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR759027',
#    u'member_id': 56,
#    u'member_type': u'member',
#    u'name': u'Zheng',
#    u'organization': u'City University of New York',
#    u'other_collaborators': u'Song Dai, Ren Guo, Marcello Lucia, Biao Wang',
#    u'photo': u'HuangZheng.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Minimal surface problems in hyperbolic manifolds and geometry of Teichm\xfcller spaces.',
#    u'surname': u'Huang',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.csi.cuny.edu/~huang/research.html'},
#   {u'mathsci_id': u'MR199039',
#    u'member_id': 57,
#    u'member_type': u'member',
#    u'name': u'Alessandra',
#    u'organization': u'Eidgen\xf6ssische Technische Hochschule Z\xfcrich',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Iozzi',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR307032',
#    u'member_id': 58,
#    u'member_type': u'member',
#    u'name': u'Lisa',
#    u'organization': u'University of Toronto',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Jeffrey',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR290412',
#    u'member_id': 59,
#    u'member_type': u'member',
#    u'name': u'Lizhen',
#    u'organization': u'University of Michigan',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ji',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR349512',
#    u'member_id': 60,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'Indiana University',
#    u'other_collaborators': u'Matthieu Gendulphe, Luc Hillairet',
#    u'photo': u'JudgeChristopher.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I am interested in the Teichm\xfcller flow on moduli space, especially closed orbits (Teichm\xfcller curves). I am also interested in Laplace spectrum of hyperbolic manifolds.',
#    u'surname': u'Judge',
#    u'title': u'GEAR Member',
#    u'website': u'http://pages.iu.edu/~cjudge/'},
#   {u'mathsci_id': u'MR600076',
#    u'member_id': 61,
#    u'member_type': u'member',
#    u'name': u'Ilya',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u"Tatiana Nagnibeda, Richard Weidmann, Paul Schupp, Armando Martino, Stefano Francaviglia, Mathieu Cerette, Ken'ici Ohshika, Woojin Jeon, Vadim Kaimanovich, Alexei Myasnikov, Vladimir Shpilrain",
#    u'photo': u'',
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'I am interested in the dynamics and geometry of the mapping class groups and of the outer automorphism group of a free group, in group actions on R-trees, in hyperbolic geometry and low-dimensional topology, and in the geometry of the Teichmuller space and its "relatives" and analogs.',
#    u'surname': u'Kapovich',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.uiuc.edu/~kapovich'},
#   {u'mathsci_id': u'MR98110',
#    u'member_id': 62,
#    u'member_type': u'member',
#    u'name': u'Michael',
#    u'organization': u'University of California, Davis',
#    u'other_collaborators': u'Arkady Berenstein, Koji Fujiwara, Tom Haines, Bruce Kleiner, Janos Kollar, Shrawan Kumar, Al Marden, John Millson, Leonid Potyagailo, Ernest Vinberg',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'Geometric topology, geometric geometry and geometric group theory.',
#    u'surname': u'Kapovich',
#    u'title': u'GEAR Member',
#    u'website': u'https://www.math.ucdavis.edu/~kapovich/'},
#   {u'mathsci_id': u'MR870875',
#    u'member_id': 63,
#    u'member_type': u'member',
#    u'name': u'Fanny',
#    u'organization': u'Universit\xe9 Lille I',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Kassel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR695970',
#    u'member_id': 64,
#    u'member_type': u'member',
#    u'name': u'Richard',
#    u'organization': u'University of Wisconsin-Madison',
#    u'other_collaborators': u'Eriko Hironaka, David Peifer, Saul Schleimer',
#    u'photo': u'KentRichard.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am interested in the interplay of algebra, geometry, and analysis in the study of moduli of hyperbolic manifolds.',
#    u'surname': u'Kent',
#    u'title': u'GEAR Member',
#    u'website': u'https://www.math.wisc.edu/~rkent'},
#   {u'mathsci_id': u'MR100420',
#    u'member_id': 65,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'Stanford University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Kerckhoff',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR611580',
#    u'member_id': 66,
#    u'member_type': u'member',
#    u'name': u'Bruno',
#    u'organization': u'Universit\xe9 Paris Diderot - Paris VII',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Klingler',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR108970',
#    u'member_id': 67,
#    u'member_type': u'member',
#    u'name': u'Fran\xe7ois',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Labourie',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR802618',
#    u'member_id': 68,
#    u'member_type': u'member',
#    u'name': u'Sean',
#    u'organization': u'George Mason University',
#    u'other_collaborators': u'Indranil Biswas, Marina Logares, Lars Louder, Ben McReynolds, Dan Ramras',
#    u'photo': u'LawtonSean.jpg',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces, Higgs Bundles, Character Varieties',
#    u'short_bio': u'The geometric, topological, algebraic, arithmetic, and dynamical structure of moduli spaces of Lie group valued representations of finitely generated groups and quivers; with applications to mathematical physics and geometric structure theory.',
#    u'surname': u'Lawton',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.gmu.edu/~slawton3/'},
#   {u'mathsci_id': u'MR688414',
#    u'member_id': 69,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Leininger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR307438',
#    u'member_id': 70,
#    u'member_type': u'member',
#    u'name': u'Enrico',
#    u'organization': u'Karlsruher Institut f\xfcr Technologie',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Leuzinger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR677695',
#    u'member_id': 71,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Loftin',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR201087',
#    u'member_id': 72,
#    u'member_type': u'member',
#    u'name': u'Darren',
#    u'organization': u'University of California, Santa Barbara',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Long',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR251419',
#    u'member_id': 73,
#    u'member_type': u'member',
#    u'name': u'Feng',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I am interested in finding geometric structures on low-dimensional spaces.',
#    u'surname': u'Luo',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR117090',
#    u'member_id': 74,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Universit\xe9 Aix-Marseille III Paul Cezanne',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Lustig',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR871811',
#    u'member_id': 75,
#    u'member_type': u'member',
#    u'name': u'Aaron',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Magid',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR690777',
#    u'member_id': 76,
#    u'member_type': u'member',
#    u'name': u'Jason',
#    u'organization': u'University at Buffalo',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Manning',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR898909',
#    u'member_id': 77,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'George Mason University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Manon',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR119725',
#    u'member_id': 78,
#    u'member_type': u'member',
#    u'name': u'Albert',
#    u'organization': u'University of Minnesota',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Marden',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR219274',
#    u'member_id': 79,
#    u'member_type': u'member',
#    u'name': u'Howard',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'Keith Burns, Jon Chaika',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I study geometry of Teichmuller space and the mapping class group. I also study the dynamics of the SL(2,R) action moduli space of translation surfaces.',
#    u'surname': u'Masur',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.uchicago.edu/~masur/'},
#   {u'mathsci_id': u'MR746899',
#    u'member_id': 80,
#    u'member_type': u'member',
#    u'name': u'Ben',
#    u'organization': u'Purdue University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'McReynolds',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR358972',
#    u'member_id': 81,
#    u'member_type': u'member',
#    u'name': u'Greg',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'McShane',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR819221',
#    u'member_id': 82,
#    u'member_type': u'member',
#    u'name': u'Karin',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'Uri Bader, Thierry Barbot, Andreas Cap, Mohammed Deffaf, Charles Frances, Katharina Neusser, Wouter van Limbeek',
#    u'photo': u'',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Differential-geometric aspects of rigidity, Lorentzian Geometry, Conformal Geometry, other parabolic geometries',
#    u'surname': u'Melnick',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.umd.edu/~karin'},
#   {u'mathsci_id': u'MR125000',
#    u'member_id': 83,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Millson',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR308303',
#    u'member_id': 84,
#    u'member_type': u'member',
#    u'name': u'Yair',
#    u'organization': u'Yale University',
#    u'other_collaborators': u'Jason Behrstock, Tsachik Gelander, Grigori Margulis, Yoav Moriah',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am interested in questions around hyperbolic manifolds, surfaces and mapping class groups, and connections to geometric group theory. For hyperbolic 3-manifolds I am interested in finding better explicit recipes for relating geometric to topological structures. Mapping class groups and other automorphism groups act on character varieties and I am interested in analysing this dynamical structure. Quasi-isometric rigidity is another topic I have worked on.',
#    u'surname': u'Minsky',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.yale.edu/users/yair'},
#   {u'mathsci_id': u'MR602134',
#    u'member_id': 85,
#    u'member_type': u'member',
#    u'name': u'Maryam',
#    u'organization': u'Stanford University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mirzakhani',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR606917',
#    u'member_id': 86,
#    u'member_type': u'member',
#    u'name': u'Mahan',
#    u'organization': u'RKM Vivekananda University',
#    u'other_collaborators': u'Gautam Bharali, Indranil Biswas, Pranab Sardar, Saul Schleimer, Harish Seshadri',
#    u'photo': u'MahanMj.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'My main interests lie at the interface of Geometric Group Theory and Kleinian groups. Another interest lies in K\xe4hler groups, fundamental groups of (quasi) projective varieties.',
#    u'surname': u'Mj',
#    u'title': u'GEAR Member',
#    u'website': u'http://maths.rkmvu.ac.in/~mahan/'},
#   {u'mathsci_id': u'MR195516',
#    u'member_id': 87,
#    u'member_type': u'member',
#    u'name': u'Motohico',
#    u'organization': u'University of California, Davis',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mulase',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR642261',
#    u'member_id': 88,
#    u'member_type': u'member',
#    u'name': u'Ignasi',
#    u'organization': u'Universitat de Barcelona',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mundet i Riera',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR130560',
#    u'member_id': 89,
#    u'member_type': u'member',
#    u'name': u'Walter',
#    u'organization': u'Columbia University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'',
#    u'surname': u'Neumann',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR931316',
#    u'member_id': 90,
#    u'member_type': u'member',
#    u'name': u'Andr\xe9 Gama',
#    u'organization': u'Universidade de Tr\xe1s-os-Montes e Alto Douro',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Oliveira',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR902682',
#    u'member_id': 91,
#    u'member_type': u'member',
#    u'name': u'Frederic',
#    u'organization': u'Aix-Marseille Universit\xe9',
#    u'other_collaborators': u'Laurent Beaudou, Gregoire Dupont, Antoine Gerbaud, Laurent Grappe',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u"I'm interested in spaces of representations of surface groups and the natural action of the mapping class group on these spaces. Also interested in the relation between Teichmuller space and cluster algebras.",
#    u'surname': u'Palesi',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.latp.univ-mrs.fr/~fpalesi/'},
#   {u'mathsci_id': u'MR135745',
#    u'member_id': 92,
#    u'member_type': u'member',
#    u'name': u'Pierre',
#    u'organization': u'\xc9cole Normale Sup\xe9rieure',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pansu',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR346256',
#    u'member_id': 93,
#    u'member_type': u'member',
#    u'name': u'Tony',
#    u'organization': u'University of Pensylvania',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pantev',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR135835',
#    u'member_id': 94,
#    u'member_type': u'member',
#    u'name': u'Athanase',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u"Norbert A'Campo, Charalampos Charitos, Mustafa Korkmaz, Lixin Liu, Yannis Papadoperakis, Roshdi Rashed, Weixu Su, Guillaume Th\xe9ret, Marc Troyanov, Sumio Yamada",
#    u'photo': u'PapadopoulosAthanase.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'Mapping class group actions, hyperbolic geometry, Finsler geometry.',
#    u'surname': u'Papadopoulos',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-irma.u-strasbg.fr/~papadop/'},
#   {u'mathsci_id': u'MR319072',
#    u'member_id': 95,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'Durham University',
#    u'other_collaborators': u'Krishnendu Gongopadhyay, Jose Seade, Shigeyasu Kamiya',
#    u'photo': u'ParkerJohn.jpg',
#    u'research_interests': u'Hyperbolic Manifolds, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'My main research is on discrete groups of complex hyperbolic isometries, and their deformation spaces. More widely, I am interested in hyperbolic geometry and discrete groups.',
#    u'surname': u'Parker',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.maths.dur.ac.uk/~dma0jrp/'},
#   {u'mathsci_id': u'MR767561',
#    u'member_id': 96,
#    u'member_type': u'member',
#    u'name': u'Hugo',
#    u'organization': u'University of Fribourg',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Parlier',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR670952',
#    u'member_id': 97,
#    u'member_type': u'member',
#    u'name': u'Anne',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Parreau',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR260394',
#    u'member_id': 98,
#    u'member_type': u'member',
#    u'name': u'Frederic',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'Alexander Gorodnik, Jouni Parkkonen, Mark Pollicott, Barbara Schapira',
#    u'photo': u'Paulin.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Equidistribution problems in locally symmetric spaces.',
#    u'short_bio': u'Ergodic theory of geodesic flows in negative curvature (counting and equidistribution, Gibbs measures, ...) and arithmetic applications. Geometric group theory (group actions on trees and buildings, ...). Discrete subgroups of Lie groups. Homogeneous dynamics and arithmetic applications.',
#    u'surname': u'Paulin',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.u-psud.fr/~paulin/'},
#   {u'mathsci_id': u'MR751601',
#    u'member_id': 99,
#    u'member_type': u'member',
#    u'name': u'Julien',
#    u'organization': u'Arizona State University',
#    u'other_collaborators': u'',
#    u'photo': u'PaupertJulien.jpg',
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'My research interests lie in low-dimensional geometry and topology. More precisely, I study hyperbolic geometry (mostly complex), reflection groups, and lattices in rank 1 semisimple Lie groups.',
#    u'surname': u'Paupert',
#    u'title': u'GEAR Member',
#    u'website': u'https://math.la.asu.edu/~paupert/'},
#   {u'mathsci_id': u'MR137745',
#    u'member_id': 100,
#    u'member_type': u'member',
#    u'name': u'Robert',
#    u'organization': u'Aarhus University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Penner',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR360380',
#    u'member_id': 101,
#    u'member_type': u'member',
#    u'name': u'Joan',
#    u'organization': u'Universitat Aut\xf2noma de Barcelona',
#    u'other_collaborators': u'Bessi\xe8res, Laurent; Besson, G\xe9rard; Dicks, Warren; Francaviglia, Stefano; Heusener, Michael; Leeb, Bernhard; Maillot, Sylvain; Menal Ferrer, Pere; Paoluzzi, Luisa',
#    u'photo': u'PortiJoan.jpg',
#    u'research_interests': u'Geometric and Analytical Group Theory, Hyperbolic Manifolds',
#    u'short_bio': u'Varieties of representations of three manifold groups. Geometric structures on three manifolds. Reidemeister torsions. Discrete subgroups of isometries of symmetric spaces.',
#    u'surname': u'Porti',
#    u'title': u'GEAR Member',
#    u'website': u'http://mat.uab.es/~porti/'},
#   {u'mathsci_id': u'MR719537',
#    u'member_id': 102,
#    u'member_type': u'member',
#    u'name': u'Kasra',
#    u'organization': u'University of Toronto',
#    u'other_collaborators': u'',
#    u'photo': u'KasraRafi.jpg',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'',
#    u'surname': u'Rafi',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.toronto.edu/~rafi/'},
#   {u'mathsci_id': u'MR146355',
#    u'member_id': 103,
#    u'member_type': u'member',
#    u'name': u'Alan',
#    u'organization': u'University of Texas at Austin',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Reid',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR1062326',
#    u'member_id': 104,
#    u'member_type': u'member',
#    u'name': u'Andr\xe9s',
#    u'organization': u'Universit\xe9 Pierre et Marie Curie',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'My main interest is to understand representations of hyperbolic groups on semi-simple Lie groups. The main objective is understand how the intrinsic geometry of the hyperbolic group interacts with that of the Lie group.',
#    u'surname': u'Sambarino',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.jussieu.fr/~sambarino/'},
#   {u'mathsci_id': u'MR695566',
#    u'member_id': 105,
#    u'member_type': u'member',
#    u'name': u'Dragomir',
#    u'organization': u'City University of New York',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Saric',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'mathsci_id': u'MR745885',
#    u'member_id': 106,
#    u'member_type': u'member',
#    u'name': u'Florent',
#    u'organization': u'Universidad de Los Andes',
#    u'other_collaborators': u'Chiu-Chu Melissa Liu',
#    u'photo': u'',
#    u'research_interests': u'Higgs Bundles, Real algebraic geometry',
#    u'short_bio': u'I work in the area at the intersection between the theory of Vector bundles on curves and Real algebraic geometry. Themes which are of special interest to me are:\n-Topology of sets of real points of moduli schemes of vector bundles on a real algebraic curve (connected components, Betti numbers).\n-Narasimhan-Seshadri, Hitchin-Kobayashi-Simpson and Donaldson-Corlette correspondences over real algebraic curves.\n\nResearch interests (AMS subject classification) :\n-Vector bundles on curves and their moduli (14H60)\n-Special connections and metrics on vector bundles (Hermite-Einstein-Yang-Mills) (53C07).\n-Topology of real algebraic varieties (14P25).',
#    u'surname': u'Schaffhauser',
#    u'title': u'GEAR Member',
#    u'website': u'http://matematicas.uniandes.edu.co/~florent'},
#   {u'mathsci_id': u'MR362432',
#    u'member_id': 107,
#    u'member_type': u'member',
# ...
#   {u'mathsci_id': u'NA',
#    u'member_id': 317,
#    u'member_type': u'graduate',
#    u'name': u'Lindsey',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gamard',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 318,
#    u'member_type': u'graduate',
#    u'name': u'Jordane',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Granier',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1034245',
#    u'member_id': 319,
#    u'member_type': u'graduate',
#    u'name': u'Mustafa',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Hajij',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 320,
#    u'member_type': u'graduate',
#    u'name': u'Son',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ho',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 321,
#    u'member_type': u'graduate',
#    u'name': u'Gahye',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Jeong',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 322,
#    u'member_type': u'graduate',
#    u'name': u'Muhammad Ali',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Khan',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR972745',
#    u'member_id': 323,
#    u'member_type': u'graduate',
#    u'name': u'Michael',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Landry',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 324,
#    u'member_type': u'graduate',
#    u'name': u'John',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Lawson',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 325,
#    u'member_type': u'graduate',
#    u'name': u'Ivan',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Levcovitz',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 326,
#    u'member_type': u'graduate',
#    u'name': u'Tianyu',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ma',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 327,
#    u'member_type': u'graduate',
#    u'name': u'Fran\xe7ois',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Malabre',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 328,
#    u'member_type': u'graduate',
#    u'name': u'Justin',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Martel',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1079618',
#    u'member_id': 329,
#    u'member_type': u'graduate',
#    u'name': u'David',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Renardy',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 330,
#    u'member_type': u'graduate',
#    u'name': u'Doreen',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Reuchsel',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 331,
#    u'member_type': u'graduate',
#    u'name': u'David',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Reynoso Valle',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 332,
#    u'member_type': u'graduate',
#    u'name': u'Anna-Sofie',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Schilling',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 333,
#    u'member_type': u'graduate',
#    u'name': u'Nicolas',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Tholozan',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1101607',
#    u'member_id': 334,
#    u'member_type': u'graduate',
#    u'name': u'Nicholas',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Vlamis',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 335,
#    u'member_type': u'graduate',
#    u'name': u'Yohsuke',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Watanabe',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 336,
#    u'member_type': u'graduate',
#    u'name': u'Joseph',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Wells',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 337,
#    u'member_type': u'graduate',
#    u'name': u'Daping',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Weng',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 338,
#    u'member_type': u'graduate',
#    u'name': u'Jonathan',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Wilson',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 339,
#    u'member_type': u'graduate',
#    u'name': u'Andrew',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Yarmola',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR993178',
#    u'member_id': 340,
#    u'member_type': u'graduate',
#    u'name': u'Ren',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Yi',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 341,
#    u'member_type': u'graduate',
#    u'name': u'Tengren',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Zhang',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 343,
#    u'member_type': u'graduate',
#    u'name': u'Du',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pei',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR866169',
#    u'member_id': 344,
#    u'member_type': u'graduate',
#    u'name': u'Tarik',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Aougab',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 345,
#    u'member_type': u'graduate',
#    u'name': u'Mark',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bell',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 346,
#    u'member_type': u'graduate',
#    u'name': u'Benoit',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cadorel',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR941342',
#    u'member_id': 347,
#    u'member_type': u'graduate',
#    u'name': u'Michael',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cantrell',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR904402',
#    u'member_id': 348,
#    u'member_type': u'graduate',
#    u'name': u'William',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cavendish',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR973224',
#    u'member_id': 349,
#    u'member_type': u'graduate',
#    u'name': u'Otis',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Chodosh',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 350,
#    u'member_type': u'graduate',
#    u'name': u'Yongfei',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ci',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 351,
#    u'member_type': u'graduate',
#    u'name': u'Vladimir',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Finkelshtein',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 352,
#    u'member_type': u'graduate',
#    u'name': u'Maxime',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Fortier Bourques',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1070495',
#    u'member_id': 353,
#    u'member_type': u'graduate',
#    u'name': u'Dominik',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Francoeur',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 354,
#    u'member_type': u'graduate',
#    u'name': u'Richard',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Hughes',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 355,
#    u'member_type': u'graduate',
#    u'name': u'Gregory',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Laun',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 356,
#    u'member_type': u'graduate',
#    u'name': u'Tong',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Li',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1084560',
#    u'member_id': 357,
#    u'member_type': u'graduate',
#    u'name': u'Brian',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mann',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 358,
#    u'member_type': u'graduate',
#    u'name': u'Robert',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Maschal',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 359,
#    u'member_type': u'graduate',
#    u'name': u'Nikita',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Nikolaev',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1061548',
#    u'member_id': 360,
#    u'member_type': u'graduate',
#    u'name': u'Alexander',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Rasmussen',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 361,
#    u'member_type': u'graduate',
#    u'name': u'Domingo',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ruiz',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 362,
#    u'member_type': u'graduate',
#    u'name': u'Partha',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Solapurkar',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1073329',
#    u'member_id': 363,
#    u'member_type': u'graduate',
#    u'name': u'Daniel',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Studenmund',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 364,
#    u'member_type': u'graduate',
#    u'name': u'Bo',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Tian',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 365,
#    u'member_type': u'graduate',
#    u'name': u'Bena',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Tshishiku',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR1059784',
#    u'member_id': 366,
#    u'member_type': u'graduate',
#    u'name': u'Wouter',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'van Limbeek',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'MR925092',
#    u'member_id': 367,
#    u'member_type': u'graduate',
#    u'name': u'Alden',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Walker',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'mathsci_id': u'NA',
#    u'member_id': 368,
#    u'member_type': u'graduate',
#    u'name': u'Yuecheng',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Zhu',
#    u'title': u'Graduate Student',
#    u'website': u''}]}

# %%
orig_profile
# Out:
# {u'groups': [{u'slug': u'member', u'title': u'GEAR Members'},
#   {u'slug': u'graduate', u'title': u'Graduate Students'},
#   {u'slug': u'postdoc', u'title': u'Postdocs'}],
#  u'items': [{u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 0,
#    u'member_type': u'member',
#    u'name': u'Ian',
#    u'organization': u'University of California, Berkeley',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Agol',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 1,
#    u'member_type': u'member',
#    u'name': u'J\xf8rgen',
#    u'organization': u'Aarhus University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Andersen',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 2,
#    u'member_type': u'member',
#    u'name': u'Jayadev',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'Jon Chaika',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces',
#    u'short_bio': u'Dynamics on moduli spaces of quadratic differentials, comparisons to dynamics on moduli spaces of lattices.',
#    u'surname': u'Athreya',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.illinois.edu/~jathreya'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 3,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'University of Adelaide',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Baraglia',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 4,
#    u'member_type': u'member',
#    u'name': u'Ara',
#    u'organization': u'City University of New York',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Basmajian',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 5,
#    u'member_type': u'member',
#    u'name': u'Mikhail',
#    u'organization': u'Instituto Nacional de Mathematica Pura e Aplicada',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Belolipetsky',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 6,
#    u'member_type': u'member',
#    u'name': u'Yves',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Benoist',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 7,
#    u'member_type': u'member',
#    u'name': u'Olivier',
#    u'organization': u'\xc9cole Normale Sup\xe9rieure',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Biquard',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 8,
#    u'member_type': u'member',
#    u'name': u'Hans',
#    u'organization': u'McMaster University',
#    u'other_collaborators': u'Cynthia Curtis, Stefan Friedl, Eric Harper, Christopher Herald, Benjamin Himpel, Paul Kirk, Andrew Nicas,',
#    u'photo': u'BodenHans.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Gauge theory and low dimensional topology',
#    u'short_bio': u'Gauge theory and low dimensional topology, moduli spaces of flat connections and character varieties. Applications to invariants of knots and 3-manifolds.',
#    u'surname': u'Boden',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.mcmaster.ca/boden'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 9,
#    u'member_type': u'member',
#    u'name': u'Michel',
#    u'organization': u'Universit\xe9 de Toulouse',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Boileau',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 10,
#    u'member_type': u'member',
#    u'name': u'Francis',
#    u'organization': u'University of Southern California',
#    u'other_collaborators': u'Qingtao Chen, Helen Wong',
#    u'photo': u'BonahonFrancis.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Geometric Group Theory',
#    u'short_bio': u'With respect to GEAR, the main thrust of my research is 2-fold. The first one is higher Teichm\xfcller theory and representations of surface groups in SL_n(R) or SL_n(C). I am also interested in developing connections between 3-dimensional hyperbolic geometry, representations of surface groups in SL_2(C), and knot invariants based on the quantum group U_q(sl_2).',
#    u'surname': u'Bonahon',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-bcf.usc.edu/~fbonahon/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 11,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'Universit\xe9 du Qu\xe9bec \xe0 Montr\xe9al',
#    u'other_collaborators': u'Adam Clay, Dale Rolfsen, Cameron Gordon, Liam Watson, Shicheng Wang, Radu Cebanu, Genevieve Walsh, Stephan Tillmann',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Low dimensional topology and geometry. Character varieties.',
#    u'short_bio': u'Low dimensional topology and geometry. Character varieties and their applications to low-dimensional manifolds.',
#    u'surname': u'Boyer',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.cirget.uqam.ca/boyer/boyer.html'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 12,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'Indranil Biswas, Jim Glazebrook, Tomas Gomez, Adam Jacob, Franz Kamber, Vincent Mercat, Vicente Munoz, Peter Newstead, Mathias Stemmler',
#    u'photo': u'BradlowSteven.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Higgs Bundles',
#    u'short_bio': u"I'm interested in moduli spaces associated with holomorphic vector bundles. In particular, I'm a big fan of applications of Higgs bundle technology to the study of surface group representation varieties. Before I die, I'd like to be able to compute the surface group representation corresponding to any given Higgs bundle, and vice versa.",
#    u'surname': u'Bradlow',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 13,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Boston College',
#    u'other_collaborators': u'Edward Taylor, Petra Bonfert-Taylor',
#    u'photo': u'BridgemanMartin.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'My current research interests are convex hulls of Kleinian groups, geometric identities on Moduli spaces and generalizations of Weil-Petersson geometry to higher Teichm\xfcller spaces. ',
#    u'surname': u'Bridgeman',
#    u'title': u'GEAR Member',
#    u'website': u'https://www2.bc.edu/~bridgem/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 14,
#    u'member_type': u'member',
#    u'name': u'Lewis',
#    u'organization': u'University of Texas at Austin',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bowen',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 15,
#    u'member_type': u'member',
#    u'name': u'Jeffrey',
#    u'organization': u'Brown University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Brock',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 16,
#    u'member_type': u'member',
#    u'name': u'Kenneth',
#    u'organization': u'University of Utah',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bromberg',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 17,
#    u'member_type': u'member',
#    u'name': u'Michelle',
#    u'organization': u'Universit\xe9 de Gen\xe8ve',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bucher',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 18,
#    u'member_type': u'member',
#    u'name': u'Marc',
#    u'organization': u'Eidgen\xf6ssische Technische Hochschule Z\xfcrich',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Burger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 19,
#    u'member_type': u'member',
#    u'name': u'Danny',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Calegari',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 20,
#    u'member_type': u'member',
#    u'name': u'Richard',
#    u'organization': u'University of Michigan',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Canary',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 21,
#    u'member_type': u'member',
#    u'name': u'Virginie',
#    u'organization': u'Universit\xe9 de Sherbrooke',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Charette',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 22,
#    u'member_type': u'member',
#    u'name': u'Daryl',
#    u'organization': u'University of California, Santa Barbara',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cooper',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 23,
#    u'member_type': u'member',
#    u'name': u'Marc',
#    u'organization': u'University of Illinois at Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Culler',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 24,
#    u'member_type': u'member',
#    u'name': u'Georgios',
#    u'organization': u'Brown University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Daskalopoulos',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 25,
#    u'member_type': u'member',
#    u'name': u'Kelly',
#    u'organization': u'Buffalo State College',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Delp',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 26,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Deraux',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 27,
#    u'member_type': u'member',
#    u'name': u'Todd',
#    u'organization': u'Howard University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Drumm',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 28,
#    u'member_type': u'member',
#    u'name': u'Moon',
#    u'organization': u'Tufts University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Duchin',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 29,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'University of Illinois at Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dumas',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 30,
#    u'member_type': u'member',
#    u'name': u'Sorin',
#    u'organization': u'Universit\xe9 de Nice Sophia-Antipolis',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dumitrescu',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 31,
#    u'member_type': u'member',
#    u'name': u'Nathan',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Dunfield',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 32,
#    u'member_type': u'member',
#    u'name': u'Alex',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'Artur Avila, Jon Chaika, Maxim Kontsevich, Carlos Matheus Santos, Martin M\xf6ller, Marcelo Viana, Anton Zorich',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory',
#    u'short_bio': u'',
#    u'surname': u'Eskin',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.uchicago.edu/~eskin'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 33,
#    u'member_type': u'member',
#    u'name': u'Elisha',
#    u'organization': u'Universit\xe9 Pierre et Marie Curie - Paris VI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Falbel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 34,
#    u'member_type': u'member',
#    u'name': u'Benson',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Farb',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 35,
#    u'member_type': u'member',
#    u'name': u'Roberto',
#    u'organization': u'Universit\xe0 di Pisa',
#    u'other_collaborators': u'Riccardo Benedetti, Bruno Martelli, Cristina Pagliantini, Carlo Petronio, Alessandro Sisto',
#    u'photo': u'FrigerioRoberto.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Bounded cohomology and simplicial volume.',
#    u'short_bio': u'I am currently working on bounded cohomology of discrete groups, with a particular attention to results and techniques related to geometric group theory. I also used to study classical hyperbolic geometry, mainly in dimension 3, and I am still interested in the geometry and topology of low-dimensional manifolds.',
#    u'surname': u'Frigerio',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.dm.unipi.it/~frigerio/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 36,
#    u'member_type': u'member',
#    u'name': u'Carlos',
#    u'organization': u'Universidade T\xe9cnica de Lisboa',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Florentino',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 37,
#    u'member_type': u'member',
#    u'name': u'Vladimir',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Fock',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 38,
#    u'member_type': u'member',
#    u'name': u'Giovanni',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Forni',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 39,
#    u'member_type': u'member',
#    u'name': u'Louis',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'Mapping class groups',
#    u'surname': u'Funar',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-fourier.ujf-grenoble.fr/~funar/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 40,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'Temple University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Futer',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 41,
#    u'member_type': u'member',
#    u'name': u'David',
#    u'organization': u'Princeton University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gabai',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 42,
#    u'member_type': u'member',
#    u'name': u'Vaibhav',
#    u'organization': u'University of Warwick',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gadre',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 43,
#    u'member_type': u'member',
#    u'name': u'Oscar',
#    u'organization': u'Consejo Superior de Investigaciones Cient\xedficas',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Garc\xeda-Prada',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 44,
#    u'member_type': u'member',
#    u'name': u'Jane',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gilman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 45,
#    u'member_type': u'member',
#    u'name': u'Yair',
#    u'organization': u'Ben-Gurion University of the Negev',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Glasner',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 46,
#    u'member_type': u'member',
#    u'name': u'William',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Goldman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 47,
#    u'member_type': u'member',
#    u'name': u'Alexander',
#    u'organization': u'Yale University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Goncharov',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 48,
#    u'member_type': u'member',
#    u'name': u'Matthias',
#    u'organization': u'Pixar Animation Studios',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'G\xf6rner',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 49,
#    u'member_type': u'member',
#    u'name': u'Peter',
#    u'organization': u'Universidade do Porto',
#    u'other_collaborators': u'I. Biswas, S.B.S.D. Castro, S. Dakhlia, A.D. King, M. Logares, V. Mu\xf1oz',
#    u'photo': u'GothenPeter.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': [u'Higgs bundles'],
#    u'short_bio': u'Geometry and topology of moduli spaces. Higgs bundles and their application to the study of character varieties of surface groups, especially for real Lie groups.',
#    u'surname': u'Gothen',
#    u'title': u'GEAR Member',
#    u'website': u'http://cmup.fc.up.pt/cmup/pbgothen/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 50,
#    u'member_type': u'member',
#    u'name': u'Marco',
#    u'organization': u'University of Toronto',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Gualtieri',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 51,
#    u'member_type': u'member',
#    u'name': u'Olivier',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u'',
#    u'photo': u'GuichardOlivier.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Main interests are convex-cocompact subgroups and generalizations, the relations between geometric and dynamical properties for discrete subgroups of Lie groups with an emphasis on "Higher Teichm\xfcller spaces".',
#    u'surname': u'Guichard',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-irma.u-strasbg.fr/~guichard/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 52,
#    u'member_type': u'member',
#    u'name': u'Rosemary',
#    u'organization': u'University of Iowa',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Guzman',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 53,
#    u'member_type': u'member',
#    u'name': u'Thomas',
#    u'organization': u'Universit\xe9 Montpellier II',
#    u'other_collaborators': u'Dawid Kielak, Petra Schwer',
#    u'photo': u'HaettelThomas.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am mainly interested in the asymptotic geometry of symmetric spaces, in degeneration of geometric structures and in the geometry of braid groups.',
#    u'surname': u'Haettel',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.univ-montp2.fr/~haettel'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 54,
#    u'member_type': u'member',
#    u'name': u'Tam\xe1s',
#    u'organization': u'Ecole Polytechnique F\xe9d\xe9rale de Lausanne',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Hausel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 55,
#    u'member_type': u'member',
#    u'name': u'Zheng',
#    u'organization': u'City University of New York',
#    u'other_collaborators': u'Song Dai, Ren Guo, Marcello Lucia, Biao Wang',
#    u'photo': u'HuangZheng.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Minimal surface problems in hyperbolic manifolds and geometry of Teichm\xfcller spaces.',
#    u'surname': u'Huang',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.csi.cuny.edu/~huang/research.html'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 56,
#    u'member_type': u'member',
#    u'name': u'Alessandra',
#    u'organization': u'Eidgen\xf6ssische Technische Hochschule Z\xfcrich',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Iozzi',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 57,
#    u'member_type': u'member',
#    u'name': u'Lisa',
#    u'organization': u'University of Toronto',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Jeffrey',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 58,
#    u'member_type': u'member',
#    u'name': u'Lizhen',
#    u'organization': u'University of Michigan',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ji',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 59,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'Indiana University',
#    u'other_collaborators': u'Matthieu Gendulphe, Luc Hillairet',
#    u'photo': u'JudgeChristopher.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I am interested in the Teichm\xfcller flow on moduli space, especially closed orbits (Teichm\xfcller curves). I am also interested in Laplace spectrum of hyperbolic manifolds.',
#    u'surname': u'Judge',
#    u'title': u'GEAR Member',
#    u'website': u'http://pages.iu.edu/~cjudge/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 60,
#    u'member_type': u'member',
#    u'name': u'Ilya',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u"Tatiana Nagnibeda, Richard Weidmann, Paul Schupp, Armando Martino, Stefano Francaviglia, Mathieu Cerette, Ken'ici Ohshika, Woojin Jeon, Vadim Kaimanovich, Alexei Myasnikov, Vladimir Shpilrain",
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'I am interested in the dynamics and geometry of the mapping class groups and of the outer automorphism group of a free group, in group actions on R-trees, in hyperbolic geometry and low-dimensional topology, and in the geometry of the Teichmuller space and its "relatives" and analogs.',
#    u'surname': u'Kapovich',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.uiuc.edu/~kapovich'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 61,
#    u'member_type': u'member',
#    u'name': u'Michael',
#    u'organization': u'University of California, Davis',
#    u'other_collaborators': u'Arkady Berenstein, Koji Fujiwara, Tom Haines, Bruce Kleiner, Janos Kollar, Shrawan Kumar, Al Marden, John Millson, Leonid Potyagailo, Ernest Vinberg',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'Geometric topology, geometric geometry and geometric group theory.',
#    u'surname': u'Kapovich',
#    u'title': u'GEAR Member',
#    u'website': u'https://www.math.ucdavis.edu/~kapovich/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 62,
#    u'member_type': u'member',
#    u'name': u'Fanny',
#    u'organization': u'Universit\xe9 Lille I',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Kassel',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 63,
#    u'member_type': u'member',
#    u'name': u'Richard',
#    u'organization': u'University of Wisconsin-Madison',
#    u'other_collaborators': u'Eriko Hironaka, David Peifer, Saul Schleimer',
#    u'photo': u'KentRichard.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am interested in the interplay of algebra, geometry, and analysis in the study of moduli of hyperbolic manifolds.',
#    u'surname': u'Kent',
#    u'title': u'GEAR Member',
#    u'website': u'https://www.math.wisc.edu/~rkent'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 64,
#    u'member_type': u'member',
#    u'name': u'Steven',
#    u'organization': u'Stanford University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Kerckhoff',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 65,
#    u'member_type': u'member',
#    u'name': u'Bruno',
#    u'organization': u'Universit\xe9 Paris Diderot - Paris VII',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Klingler',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 66,
#    u'member_type': u'member',
#    u'name': u'Fran\xe7ois',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Labourie',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 67,
#    u'member_type': u'member',
#    u'name': u'Sean',
#    u'organization': u'George Mason University',
#    u'other_collaborators': u'Indranil Biswas, Marina Logares, Lars Louder, Ben McReynolds, Dan Ramras',
#    u'photo': u'LawtonSean.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces, Higgs Bundles, Character Varieties',
#    u'short_bio': u'The geometric, topological, algebraic, arithmetic, and dynamical structure of moduli spaces of Lie group valued representations of finitely generated groups and quivers; with applications to mathematical physics and geometric structure theory.',
#    u'surname': u'Lawton',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.gmu.edu/~slawton3/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 68,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'University of Illinois at Urbana-Champaign',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Leininger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 69,
#    u'member_type': u'member',
#    u'name': u'Enrico',
#    u'organization': u'Karlsruher Institut f\xfcr Technologie',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Leuzinger',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 70,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Loftin',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 71,
#    u'member_type': u'member',
#    u'name': u'Darren',
#    u'organization': u'University of California, Santa Barbara',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Long',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 72,
#    u'member_type': u'member',
#    u'name': u'Feng',
#    u'organization': u'Rutgers University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I am interested in finding geometric structures on low-dimensional spaces.',
#    u'surname': u'Luo',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 73,
#    u'member_type': u'member',
#    u'name': u'Martin',
#    u'organization': u'Universit\xe9 Aix-Marseille III Paul Cezanne',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Lustig',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 74,
#    u'member_type': u'member',
#    u'name': u'Aaron',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Magid',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 75,
#    u'member_type': u'member',
#    u'name': u'Jason',
#    u'organization': u'University at Buffalo',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Manning',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 76,
#    u'member_type': u'member',
#    u'name': u'Christopher',
#    u'organization': u'George Mason University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Manon',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 77,
#    u'member_type': u'member',
#    u'name': u'Albert',
#    u'organization': u'University of Minnesota',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Marden',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 78,
#    u'member_type': u'member',
#    u'name': u'Howard',
#    u'organization': u'University of Chicago',
#    u'other_collaborators': u'Keith Burns, Jon Chaika',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'I study geometry of Teichmuller space and the mapping class group. I also study the dynamics of the SL(2,R) action moduli space of translation surfaces.',
#    u'surname': u'Masur',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.uchicago.edu/~masur/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 79,
#    u'member_type': u'member',
#    u'name': u'Ben',
#    u'organization': u'Purdue University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'McReynolds',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 80,
#    u'member_type': u'member',
#    u'name': u'Greg',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'McShane',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 81,
#    u'member_type': u'member',
#    u'name': u'Karin',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'Uri Bader, Thierry Barbot, Andreas Cap, Mohammed Deffaf, Charles Frances, Katharina Neusser, Wouter van Limbeek',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'Differential-geometric aspects of rigidity, Lorentzian Geometry, Conformal Geometry, other parabolic geometries',
#    u'surname': u'Melnick',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.umd.edu/~karin'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 82,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'University of Maryland-College Park',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Millson',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 83,
#    u'member_type': u'member',
#    u'name': u'Yair',
#    u'organization': u'Yale University',
#    u'other_collaborators': u'Jason Behrstock, Tsachik Gelander, Grigori Margulis, Yoav Moriah',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'I am interested in questions around hyperbolic manifolds, surfaces and mapping class groups, and connections to geometric group theory. For hyperbolic 3-manifolds I am interested in finding better explicit recipes for relating geometric to topological structures. Mapping class groups and other automorphism groups act on character varieties and I am interested in analysing this dynamical structure. Quasi-isometric rigidity is another topic I have worked on.',
#    u'surname': u'Minsky',
#    u'title': u'GEAR Member',
#    u'website': u'http://math.yale.edu/users/yair'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 84,
#    u'member_type': u'member',
#    u'name': u'Maryam',
#    u'organization': u'Stanford University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mirzakhani',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 85,
#    u'member_type': u'member',
#    u'name': u'Mahan',
#    u'organization': u'RKM Vivekananda University',
#    u'other_collaborators': u'Gautam Bharali, Indranil Biswas, Pranab Sardar, Saul Schleimer, Harish Seshadri',
#    u'photo': u'MahanMj.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory',
#    u'short_bio': u'My main interests lie at the interface of Geometric Group Theory and Kleinian groups. Another interest lies in K\xe4hler groups, fundamental groups of (quasi) projective varieties.',
#    u'surname': u'Mj',
#    u'title': u'GEAR Member',
#    u'website': u'http://maths.rkmvu.ac.in/~mahan/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 86,
#    u'member_type': u'member',
#    u'name': u'Motohico',
#    u'organization': u'University of California, Davis',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mulase',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 87,
#    u'member_type': u'member',
#    u'name': u'Ignasi',
#    u'organization': u'Universitat de Barcelona',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mundet i Riera',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 88,
#    u'member_type': u'member',
#    u'name': u'Walter',
#    u'organization': u'Columbia University',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'',
#    u'surname': u'Neumann',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 89,
#    u'member_type': u'member',
#    u'name': u'Andr\xe9 Gama',
#    u'organization': u'Universidade de Tr\xe1s-os-Montes e Alto Douro',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Oliveira',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 90,
#    u'member_type': u'member',
#    u'name': u'Frederic',
#    u'organization': u'Aix-Marseille Universit\xe9',
#    u'other_collaborators': u'Laurent Beaudou, Gregoire Dupont, Antoine Gerbaud, Laurent Grappe',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Dynamics on Moduli Spaces, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u"I'm interested in spaces of representations of surface groups and the natural action of the mapping class group on these spaces. Also interested in the relation between Teichmuller space and cluster algebras.",
#    u'surname': u'Palesi',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.latp.univ-mrs.fr/~fpalesi/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 91,
#    u'member_type': u'member',
#    u'name': u'Pierre',
#    u'organization': u'\xc9cole Normale Sup\xe9rieure',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pansu',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 92,
#    u'member_type': u'member',
#    u'name': u'Tony',
#    u'organization': u'University of Pensylvania',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pantev',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 93,
#    u'member_type': u'member',
#    u'name': u'Athanase',
#    u'organization': u'Universit\xe9 de Strasbourg',
#    u'other_collaborators': u"Norbert A'Campo, Charalampos Charitos, Mustafa Korkmaz, Lixin Liu, Yannis Papadoperakis, Roshdi Rashed, Weixu Su, Guillaume Th\xe9ret, Marc Troyanov, Sumio Yamada",
#    u'photo': u'PapadopoulosAthanase.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds',
#    u'short_bio': u'Mapping class group actions, hyperbolic geometry, Finsler geometry.',
#    u'surname': u'Papadopoulos',
#    u'title': u'GEAR Member',
#    u'website': u'http://www-irma.u-strasbg.fr/~papadop/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 94,
#    u'member_type': u'member',
#    u'name': u'John',
#    u'organization': u'Durham University',
#    u'other_collaborators': u'Krishnendu Gongopadhyay, Jose Seade, Shigeyasu Kamiya',
#    u'photo': u'ParkerJohn.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Hyperbolic Manifolds, Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces',
#    u'short_bio': u'My main research is on discrete groups of complex hyperbolic isometries, and their deformation spaces. More widely, I am interested in hyperbolic geometry and discrete groups.',
#    u'surname': u'Parker',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.maths.dur.ac.uk/~dma0jrp/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 95,
#    u'member_type': u'member',
#    u'name': u'Hugo',
#    u'organization': u'University of Fribourg',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Parlier',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 96,
#    u'member_type': u'member',
#    u'name': u'Anne',
#    u'organization': u'Universit\xe9 de Grenoble',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Parreau',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 97,
#    u'member_type': u'member',
#    u'name': u'Frederic',
#    u'organization': u'Universit\xe9 Paris-Sud - Paris XI',
#    u'other_collaborators': u'Alexander Gorodnik, Jouni Parkkonen, Mark Pollicott, Barbara Schapira',
#    u'photo': u'Paulin.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Geometric Structures and Teichm\xfcller Spaces, Hyperbolic Manifolds, Equidistribution problems in locally symmetric spaces.',
# ...
#    u'name': u'Yohsuke',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Watanabe',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 335,
#    u'member_type': u'graduate',
#    u'name': u'Joseph',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Wells',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 336,
#    u'member_type': u'graduate',
#    u'name': u'Daping',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Weng',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 337,
#    u'member_type': u'graduate',
#    u'name': u'Jonathan',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Wilson',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 338,
#    u'member_type': u'graduate',
#    u'name': u'Andrew',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Yarmola',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 339,
#    u'member_type': u'graduate',
#    u'name': u'Ren',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Yi',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 340,
#    u'member_type': u'graduate',
#    u'name': u'Tengren',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Zhang',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 342,
#    u'member_type': u'graduate',
#    u'name': u'Du',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Pei',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 343,
#    u'member_type': u'graduate',
#    u'name': u'Tarik',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Aougab',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 344,
#    u'member_type': u'graduate',
#    u'name': u'Mark',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Bell',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 345,
#    u'member_type': u'graduate',
#    u'name': u'Benoit',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cadorel',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 346,
#    u'member_type': u'graduate',
#    u'name': u'Michael',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cantrell',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 347,
#    u'member_type': u'graduate',
#    u'name': u'William',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Cavendish',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 348,
#    u'member_type': u'graduate',
#    u'name': u'Otis',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Chodosh',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 349,
#    u'member_type': u'graduate',
#    u'name': u'Yongfei',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ci',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 350,
#    u'member_type': u'graduate',
#    u'name': u'Vladimir',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Finkelshtein',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 351,
#    u'member_type': u'graduate',
#    u'name': u'Maxime',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Fortier Bourques',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 352,
#    u'member_type': u'graduate',
#    u'name': u'Dominik',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Francoeur',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 353,
#    u'member_type': u'graduate',
#    u'name': u'Richard',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Hughes',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 354,
#    u'member_type': u'graduate',
#    u'name': u'Gregory',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Laun',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 355,
#    u'member_type': u'graduate',
#    u'name': u'Tong',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Li',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 356,
#    u'member_type': u'graduate',
#    u'name': u'Brian',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Mann',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 357,
#    u'member_type': u'graduate',
#    u'name': u'Robert',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Maschal',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 358,
#    u'member_type': u'graduate',
#    u'name': u'Nikita',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Nikolaev',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 359,
#    u'member_type': u'graduate',
#    u'name': u'Alexander',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Rasmussen',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 360,
#    u'member_type': u'graduate',
#    u'name': u'Domingo',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Ruiz',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 361,
#    u'member_type': u'graduate',
#    u'name': u'Partha',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Solapurkar',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 362,
#    u'member_type': u'graduate',
#    u'name': u'Daniel',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Studenmund',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 363,
#    u'member_type': u'graduate',
#    u'name': u'Bo',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Tian',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 364,
#    u'member_type': u'graduate',
#    u'name': u'Bena',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Tshishiku',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 365,
#    u'member_type': u'graduate',
#    u'name': u'Wouter',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'van Limbeek',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 366,
#    u'member_type': u'graduate',
#    u'name': u'Alden',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Walker',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 367,
#    u'member_type': u'graduate',
#    u'name': u'Yuecheng',
#    u'organization': u'',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Zhu',
#    u'title': u'Graduate Student',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 368,
#    u'member_type': u'member',
#    u'name': u'Ted',
#    u'organization': u'University of Pennsylvania',
#    u'other_collaborators': u'David Harbater, Robert Guralnick, Frauke Bleher, George Pappas, Martin Taylor, Ralph Greenberg, Romyar Sharifi, Mahesh Kakde, Christophe Soule, Quentin Guignard, Peter Symonds, Bjorn Poonen, Rachel Pries, Nadia Heninger, Brett Hemenway, Zach Scherr, Eduardo Friedman, James Sundstrom, Aristides Kontogeorgis, Amy Ksir',
#    u'photo': u'ChinburgTed.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric and Analytical Group Theory, Hyperbolic Manifolds, applications of number theory to geometry',
#    u'short_bio': u"I'm interested in applications of number theory and arithmetic geometry to hyperbolic geometry and the theory of discrete groups. Some particular applications have been to volumes, closed geodesics, length spectra, commensurability classes and invariant quaternion algebras.",
#    u'surname': u'Chinburg',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.math.upenn.edu/~ted'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 369,
#    u'member_type': u'member',
#    u'name': u'Max',
#    u'organization': u'University of Oklahoma',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Forester',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 370,
#    u'member_type': u'member',
#    u'name': u'Yael',
#    u'organization': u'University of Haifa',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Algom-Kfir',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 371,
#    u'member_type': u'member',
#    u'name': u'Andrew',
#    u'organization': u'The University of Texas at Austin',
#    u'other_collaborators': u'Davide Gaiotto, Greg Moore, Lotte Hollands, Cumrun Vafa, Sergio Cecotti, Anindya Dey, Boris Pioline, Sergei Alexandrov, Tom Mainiero, Dmitry Galakhov, Pietro Longhi',
#    u'photo': u'NeitzkeAndrew.jpg',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'Geometric Structures and Teichm\xfcller Spaces, Higgs Bundles',
#    u'short_bio': u"I work on supersymmetric quantum field theory. Recently the study of 'quantum field theories of class S' has turned out to be closely connected to the moduli space of Higgs bundles.",
#    u'surname': u'Neitzke',
#    u'title': u'GEAR Member',
#    u'website': u'http://www.ma.utexas.edu/users/neitzke/'},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 372,
#    u'member_type': u'member',
#    u'name': u'Saul',
#    u'organization': u'University of Warwick',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Schleimer',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 373,
#    u'member_type': u'member',
#    u'name': u'Helen',
#    u'organization': u'Carleton College',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Wong',
#    u'title': u'GEAR Member',
#    u'website': u''},
#   {u'cluster_id': 0,
#    u'gear_collaborators': [],
#    u'member_id': 374,
#    u'member_type': u'member',
#    u'name': u'Goulnara',
#    u'organization': u'University of Vienna',
#    u'other_collaborators': u'',
#    u'photo': u'',
#    u'pos_x': 0,
#    u'pos_y': 0,
#    u'research_interests': u'',
#    u'short_bio': u'',
#    u'surname': u'Arzhantseva',
#    u'title': u'GEAR Member',
#    u'website': u''}]}

# %%
gear_mathsci_mapper = {}
mathsci_gear_mapper = {}

for person in math_profile['items']:
    gear_mathsci_mapper[person['member_id']] = person['mathsci_id']
    mathsci_gear_mapper[person['mathsci_id']] = person['member_id']

# %% [markdown]
# # Retrieve papers for each professor

# %% [markdown]
# ### Construct paper_set: mathsci_id -> paper_list mapping

# %%
bar = pyprind.ProgBar(len(orig_profile['items']), bar_char='█', width=70)

paper_set = {}

for person in mathsci_profile['items']:
    
    bar.update()
    
    member_id = person['member_id']
    mathsci_id = person['mathsci_id']
    
    if mathsci_id != 'NA':
        paper_set[mathsci_id] = mathscinet.find_papers(mathsci_id)
# Out:
# 0%                                                                  100%
# [                                                                      ]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-4aed6da24317> in <module>()
#       8
#       9     member_id = person['member_id']
# ---> 10     mathsci_id = person['mathsci_id']
#      11
#      12     if mathsci_id != 'NA':
#
# KeyError: 'mathsci_id'

# %%
with open("mathscinet_paper_base.json", "wb") as f:
    json.dump(paper_set, f)

# %%
with open("mathscinet_paper_base.json", "rb") as f:
    paper_set = json.load(f)

# %% [markdown]
# # Profile Update

# %% [markdown]
# ### 1. Retrieving papers

# %%
paper_set_2011 = {}
count_2011 = 0

for mathsci_id in paper_set.keys():
    
    paper_set_2011[mathsci_id] = []
    
    for paper in paper_set[mathsci_id]:
        if paper['year'] >= 2011:
            count_2011 += 1
            paper_set_2011[mathsci_id].append(paper)

print "Completed! count:", count_2011

# %% [markdown]
# ### 2. Retrieving citations

# %%
bar = pyprind.ProgBar(count_2011, bar_char='█', width=70)

for mathsci_id in paper_set_2011.keys():
    
    for paper in paper_set_2011[mathsci_id]:
        bar.update()
        paper['citing'] = mathscinet.find_parent_citations(paper['article_id'])

# %%
with open("mathscinet_paper_base_with_citation.json", "wb") as f:
    json.dump(paper_set_2011, f)

# %%
with open("mathscinet_paper_base_with_citation.json", "rb") as f:
    paper_set_2011 = json.load(f)

# %% [markdown]
# ### 3. Updating the profile accordingly

# %%
# build mapping id_converter: mathsci_id -> member_id

id_converter = {}

for person in orig_profile['items']:
    id_converter[person['mathsci_id']] = person['member_id']

# %% [markdown]
# #### 3.1 Update collaborator

# %%
def update_collaborators(cprofile, cpaper_set, starting_year, ending_year, converter):
    col_key = "%s-%s collaborators stats" % (str(starting_year), str(ending_year))
    print col_key
    for person in cprofile['items']:
        
        collab_list = []
        
        mathsci_id = person['mathsci_id']
        if mathsci_id == "NA":
            continue
        for paper in cpaper_set[mathsci_id]:
            year = paper['year']
            if year < starting_year or year > ending_year:
                continue
            authors = ["MR"+au for au in paper['authors']]
            for au in authors:
                if au in converter:
                    collab_list.append(converter[au])
                    
        person[col_key] = dict(collections.Counter(collab_list))
        
    print "Done"

# %%
for ending_year in range(2011, 2016):
    update_collaborators(orig_profile, paper_set_2011, 2011, ending_year, id_converter)

# %% [markdown]
# #### 3.2 Update citation

# %%
def retrieve_citations(person, cpaper_set, starting_year, ending_year):
    
    mathsci_id = person['mathsci_id']
    
    ret = []
    
    if mathsci_id == "NA":
        return ret
    
    paper_list = cpaper_set[mathsci_id]
    
    for paper in paper_list:
        year = paper['year']
        if year < starting_year or year > ending_year:
            continue
        ret.extend(paper['citing'])
        
    return ret

# %%
def list_overlap(list_a, list_b):

    a_multiset = collections.Counter(list_a)
    b_multiset = collections.Counter(list_b)

    overlap = list((a_multiset & b_multiset).elements())
    
    return overlap

# %%
def update_citations(cprofile, cpaper_set, starting_year, ending_year, converter):
    
    cit_key = "%s-%s citation stats" % (str(starting_year), str(ending_year))
    print cit_key    
    
    # build member_id -> person mapping
    temp_profile = {}
    for person in cprofile['items']:
        member_id = person['member_id']
        temp_profile[member_id] = person
        
    au_list = temp_profile.keys()

    for person in cprofile['items']:
        person[cit_key] = {}
        
        member_id = person['member_id']
        
        for other_person_id in au_list:
            if other_person_id == member_id:
                continue
            other_person = temp_profile[other_person_id]
            
            other_person_citation = retrieve_citations(other_person, cpaper_set, starting_year, ending_year)
            this_person_citation = retrieve_citations(person, cpaper_set, starting_year, ending_year)

            weight = len(list_overlap(other_person_citation, this_person_citation))
            if weight != 0:
                person[cit_key][other_person_id] = weight
            
    print "Done"

# %%
for ending_year in range(2011, 2016):
    update_citations(orig_profile, paper_set_2011, 2011, ending_year, id_converter)

# %%
orig_profile

# %% [markdown]
# # Visualize

# %%
#The package which handles the graph objects
import networkx as nx

# Matplotlib is the default package for
# rendering the graphs
import matplotlib.pyplot as plt

def simple_graph(profile):

    #create an empty graph
    G = nx.Graph()
    
    name_mapping = {}
    
    for person in profile['items']:
        aid = person['member_id']
        name = person['name']
        surname = person['surname']
        name_mapping[aid] = name + " " + surname
        
    for person in profile['items']:
        aid = person['member_id']
        cite = person['2011-2015 citation stats']
        for au in cite.keys():
            edge = (aid, au)
            # name_edge = (name_mapping[aid], name_mapping[au])
            # G.add_edge(name_edge[0], name_edge[1])
            G.add_edge(str(edge[0]), str(edge[1]))
    
    #draw the graph
    nx.draw(G)
    # plt.savefig("graph.png", dpi=1000)
    #show
    plt.show()

    app = Viewer(G)
    app.mainloop()
simple_graph(orig_profile)

# %%
def similarity_calculator(first, second):
    #if type(first) is not unicode:
    #    first = unicode(first, 'utf-8')
    #if type(second) is not unicode:
    #    second = unicode(second, 'utf-8')


    # 1. fuzzy matcher
    fr = fuzz.ratio(first, second)
    pr = fuzz.partial_ratio(first, second)
    sor = fuzz.token_sort_ratio(first, second)
    ser = fuzz.token_set_ratio(first, second)    
    
    # 2. sequence similarity
    s = difflib.SequenceMatcher(lambda x: x == " ", first, second)
    seq = round(s.ratio(), 3)
    
    # 3. edit distance
    # 3.1 absolute
    try:
        lv_ab = Levenshtein.distance(first, second)
    except:
        print "ooops", first, second
    
    # 3.2 jaro
    lv_ja = Levenshtein.jaro(first, second)
    
    # 3.3 jaro_winkler
    lv_jaw = Levenshtein.jaro_winkler(first, second)
    
    # 3.4 ratio
    lv_ra = Levenshtein.ratio(first, second)
    

    # 4 jarcard and 
    sr = distance.sorensen(first, second)
    ja = distance.jaccard(first, second)
    print fr, pr, sor, ser, seq, lv_ab, lv_ja, lv_jaw, lv_ra

# %%
fuzz.ratio('Andersen, J\xf8rgen E.; Chekhov, Leonid O.; Penner, R. C.; Reidys, Christian M.; Su\u0142kowski, Piotr Topological recursion for chord diagrams, RNA complexes, and cells in moduli spaces. Nuclear Phys. B 866 (2013), no. 3, 414\u2013443.', \
           'Ande J\xf8rgen E.; Chekhov, Leonid O Penner, R. C.; Reidys, Christian M.; Su\u0142kowski, Piotr Topological recursion for chord diagrams, RNAcomplexes,and cells in moduli spaces. Nuclear Phys. B 866 (2013), no. 3, 4142013443.')

# %% [markdown]
# # Computer number of paper they wrote together between y1 and y2

# %%
def count_coop(gid1, gid2, y1, y2):
    val = 0
    aid1 = base[gid1]
    aid2 = base[gid2]
    # print aid1, aid2
    papers_1 = paper_base[aid1]
    # papers_2 = paper_base[aid2]
    
    for paper in papers_1:
        if paper['year'] >= y1 and paper['year']<= y2:
            if aid2 in paper['authors']:
                val += 1
    return val

# %%
# 24
# 12

# %%
count_coop("24","12",1000,2016)

# %%
data = {}
for a1 in base.keys():
    data[a1] = {}
    for a2 in base.keys():
        if a1 is not a2:
            data[a1][a2] = count_coop(a1, a2, 2011, 2011)

# %%
with open("input.csv", "w") as f:
    f.write("Source;Target;Weight;Type\n")
    for a1 in data.keys():
        for a2 in data[a1].keys():
            if data[a1][a2] > 0:
                f.write(a1)
                f.write(";")
                f.write(a2)
                f.write(";")
                f.write(str(data[a1][a2]))
                f.write(";")
                f.write("undirected\n")

# %%
def print_single_year(year):
    data = {}
    for a1 in base.keys():
        data[a1] = {}
        for a2 in base.keys():
            if a1 is not a2:
                data[a1][a2] = count_coop(a1, a2, year, year)
                
    with open(str(year)+"_input.csv", "w") as f:
        f.write("Source;Target;Weight;Type\n")
        for a1 in data.keys():
            for a2 in data[a1].keys():
                if data[a1][a2] > 0:
                    f.write(a1)
                    f.write(";")
                    f.write(a2)
                    f.write(";")
                    f.write(str(data[a1][a2]))
                    f.write(";")
                    f.write("undirected\n")

# %%
print_single_year(2011)
print_single_year(2012)
print_single_year(2013)
print_single_year(2014)
print_single_year(2015)
print_single_year(2016)

# %% [markdown]
# # Combine databases

# %%
orig = "Boileau, Michel; Boyer, Steven; Cebanu, Radu; Walsh, Genevieve S. Knot commensurability and the Berge conjecture. Geom. Topol. 16 (2012), no. 2, 625–664."
new = 'Knot commensurability and the Berge conjecture.'

# %%
orig = "Steven B. Bradlow"
new = "Bradlow, S"

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import math
import wikipedia
import Levenshtein
import difflib
import distance
import textblob
import numpy

# %%
import json
with open("papers.json") as f:
    old_base = json.loads(f.read())

# %%
old_base.keys()

# %%
paper_base

# %%
# make a mapping from 
mapping = {}
for key in base.keys():
    mapping[base[key]] = key
    
mapping

# %%
# go through paper_base, filter only 2011+ papers

out = []
for key in paper_base.keys():
    paper_list = paper_base[key]
    for paper in paper_list:
        if paper['year'] >= 2011:
            if check_if_coop(paper['authors'], mapping):
                newone = {}
                newone['collaborator_ids'] = get_ids(paper['authors'], mapping)
                newone['date'] = str(paper['year'])
                newone['description'] = paper['article_title']
                out.append(newone)

# %%
out_base = []
for unit in out:
    f = True
    for exi in out_base:
        if unit['description'] == exi['description']:
            f = False
    if f:
        out_base.append(unit)

# %%
len(out_base)

# %%
out_base

# %%
def check_if_coop(authors, mapping):
    val = 0
    for au in authors:
        if au in mapping.keys():
            val += 1
    if val>=2:
        return True
    else:
        return False
    
def get_ids(authors, mapping):
    ret = []
    for au in authors:
        if au in mapping.keys():
            ret.append(int(mapping[au]))
    return ret

# %%
# out is auto database
# old_base is old database

final = []

for a in old_base['papers']:
    f = True
    for b in final:
        if title_compare(a, b) is True:
            f = False
    if f:
        final.append(a)
        
for a in out_base:
    f = True
    for b in final:
        if title_compare(a, b) is True:
            f = False
    if f:
        final.append(a)

# %%
len(old_base['papers'])

# %%
len(final)

# %%
def title_compare(a, b):
    return fuzz.partial_ratio(a['description'], b['description'])>95

# %%
def ids_compare(a, b):
    return set(a['collaborator_ids']) == set(b['collaborator_ids'])

# %%
def date_compare(a, b):
    return a['date'] == b['date']

# %%
with open("prof.txt", "r") as f:
    profile = json.loads(f.read())

# %%
for prof in profile['items']:
    id = prof['member_id']
    try:
        prof[u'mathsci_id'] = mapping[id]
    except:
        prof[u'mathsci_id'] = 0

# %%
profile

# %%
import json
with open('new_profile.json', 'w') as outfile:
    json.dump(profile, outfile)

# %%
import json
with open('new_papers.json', 'w') as outfile:
    json.dump(final, outfile)

# %%
"ddd  ".strip()

# %%
import collections

# %%
a = [3,4,5,5,5,6]
b = [1,3,4,4,5,5,6,7]

a_multiset = collections.Counter(a)
b_multiset = collections.Counter(b)

overlap = list((a_multiset & b_multiset).elements())

# %%
overlap

# %%
import community
import networkx as nx
import matplotlib.pyplot as plt

#better with karate_graph() as defined in networkx example.
#erdos renyi don't have true community structure
G = nx.erdos_renyi_graph(30, 0.05)

#first compute the best partition
partition = community.best_partition(G)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G,pos, alpha=0.5)
plt.show()

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
