# %%
import sys
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf-8')

# %%
def get_status(div):
    article_status_tag = div.find('a', attrs = {"class":"item_status"})
    try:
        return article_status_tag.text
    except:
        return ""

def get_text(div):
    spaced_text = " ".join(item.strip() for item in div.findAll(text=True))
    return spaced_text

def clean_text(title_text):
    no_newline_text = title_text.replace("\n", "")
    reduced_spaced_text = " ".join(no_newline_text.split())
    return reduced_spaced_text

def get_desc(div):
    full_text = get_text(div)
    article_status = get_status(div)
    
    index = full_text.find(article_status)
    start_index = index + len(article_status)
    end_index = full_text.find('SFXButton')
    
    return clean_text(full_text[start_index: end_index])

# %%
def get_article_year(div):
    full_text = get_text(div)
    for year in range(2000, 2017):
        if str(year) in get_desc(div):
            return year
    return -1

def get_article_date(div):
    return get_desc(div)

def get_article_id(div):
    num_tag = div.find('a', attrs = {"class":"mrnum"})
    return num_tag.text[2:]

def get_article_url(div):
    prefix = 'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1='
    article_id = get_article_id(div)
    return prefix + article_id

def get_article_desc(div):
    return get_desc(div)

# %%
def find_papers(mid):
    if "MR" in mid:
        mid = mid[2:]
        
    prefix = "http://www.ams.org/mathscinet/search/publications.html?pg1=INDI&s1="
    suffix = "&vfpref=html&r=1&extend=1"
    url = prefix + mid + suffix
    
    page = urllib2.urlopen(url).read()
    soup = BeautifulSoup.BeautifulSoup(page)
    divList = soup.findAll('div', attrs={ "class" : "headlineText"})
    info_list = []
    for div in divList:
            info = {}
            info['id'] = get_article_id(div)
            info['url'] = get_article_url(div)
            info['description'] = get_article_desc(div)
            info['date'] = get_article_year(div)
            info_list.append(info)
    return info_list

# %%
import scrapy
import requests
import urllib2
import BeautifulSoup
import pickle
import pyprind

# %%
url='http://www.ams.org/mathscinet/search/publications.html?pg1=INDI&s1=667103'

# %%
{
      "date":"2013",
      "description":"Andersen, J. E.; Penner, R. C.; Reidys, C. M.; Waterman, M. S. Topological classification and enumeration of RNA structures by genus. J. Math. Biol. 67 (2013), no. 5, 1261\u20131278.",
      "publication":"journal",
      "id":"1",
      "collaborator_ids":[
         1,
         99
      ]
   },

# %%
il = find_papers('153290')

# %%
il
# Out:
# [{'date': 2014,
#   'description': u'de Silva, Vin ; Robbin, Joel W. ; Salamon, Dietmar A. Combinatorial Floer homology. Mem. Amer. Math. Soc. 230 (2014), no. 1080, v+114. ISBN: 978-0-8218-9886-4 57R58',
#   'id': u'3205426',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=3205426'},
#  {'date': 2013,
#   'description': u'Massuyeau, Gw\xe9na\xebl ; Oancea, Alexandru ; Salamon, Dietmar A. Lefschetz fibrations, intersection numbers, and representations of the framed braid group. Bull. Math. Soc. Sci. Math. Roumanie (N.S.) 56(104) (2013), no. 4, 435\u2013486. (Reviewer: Meirav Topol) 14D05 (20F36)',
#   'id': u'3157093',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=3157093'},
#  {'date': 2013,
#   'description': u'Salamon, Dietmar Uniqueness of symplectic structures. Acta Math. Vietnam. 38 (2013), no. 1, 123\u2013144. (Reviewer: Philippe Rukimbira) 53D35',
#   'id': u'3098204',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1

#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2299744'},
#  {'date': 2006,
#   'description': u'Salamon, D. A. ; Weber, J. Floer homology and the heat flow. Geom. Funct. Anal. 16 (2006), no. 5, 1050\u20131138. (Reviewer: David E. Hurtubise) 53D40 (58J35)',
#   'id': u'2276534',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2276534'},
#  {'date': 2006,
#   'description': u'Robbin, Joel W. ; Salamon, Dietmar A. A construction of the Deligne-Mumford orbifold. J. Eur. Math. Soc. (JEMS) 8 (2006), no. 4, 611\u2013699. 32G15 (14H15)',
#   'id': u'2262197',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2262197'},
#  {'date': 2006,
#   'description': u'Cieliebak, Kai ; Salamon, Dietmar Wall crossing for symplectic vortices and quantum cohomology. Math. Ann. 335 (2006), no. 1, 133\u2013192. (Reviewer: Michael J. Usher) 53D45',
#   'id': u'2217687',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2217687'},
#  {'date': 2005,
#   'description': u'Gaio, Ana Rita Pires ; Salamon, Dietmar A. Gromov-Witten invariants of symplectic quotients and adiabatic limits. J. Symplectic Geom. 3 (2005), no. 1, 55\u2013159. 53D45',
#   'id': u'2198773',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2198773'},
#  {'date': 2004,
#   'description': u'Salamon, Dietmar A. The Kolmogorov-Arnold-Moser theorem. Math. Phys. Electron. J. 10 (2004), Paper 3, 37 pp. (electronic). (Reviewer: Enrico Valdinoci) 37J40 (70H08)',
#   'id': u'2111297',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2111297'},
#  {'date': 2004,
#   'description': u'McDuff, Dusa ; Salamon, Dietmar $J$ J -holomorphic curves and symplectic topology. American Mathematical Society Colloquium Publications, 52. American Mathematical Society, Providence, RI, 2004. xii+669 pp. ISBN: 0-8218-3485-1 (Reviewer: Ignasi Mundet-Riera) 53D45 (32Q65 53D40 57R17)',
#   'id': u'2045629',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2045629'},
#  {'date': 2003,
#   'description': u'Gautschi, Ralf ; Robbin, Joel W. ; Salamon, Dietmar A. Heegaard splittings and Morse-Smale flows. Int. J. Math. Math. Sci. 2003, no. 56, 3539\u20133572. (Reviewer: Dave Auckly) 57R58 (37D15 37E99)',
#   'id': u'2020083',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=2020083'},
#  {'date': 2003,
#   'description': u'Biran, Paul ; Polterovich, Leonid ; Salamon, Dietmar Propagation in Hamiltonian dynamics and relative symplectic homology. Duke Math. J. 119 (2003), no. 1, 65\u2013118. (Reviewer: Klaus Mohnke) 53D40 (32Q28 37J05)',
#   'id': u'1991647',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1991647'},
#  {'date': 2003,
#   'description': u'Cieliebak, Kai ; Mundet i Riera, Ignasi ; Salamon, Dietmar A. Equivariant moduli problems, branched manifolds, and the Euler class. Topology 42 (2003), no. 3, 641\u2013700. (Reviewer: David E. Hurtubise) 53D45 (55N91 57R20 58B15)',
#   'id': u'1953244',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1953244'},
#  {'date': 2002,
#   'description': u'Cieliebak, Kai ; Gaio, A. Rita ; Mundet i Riera, Ignasi ; Salamon, Dietmar A. The symplectic vortex equations and invariants of Hamiltonian group actions. J. Symplectic Geom. 1 (2002), no. 3, 543\u2013645. (Reviewer: Klaus Mohnke) 53D45 (53D20 57R57 57S25)',
#   'id': u'1959059',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=

#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1392663'},
#  {'date': -1,
#   'description': u'McDuff, Dusa ; Salamon, Dietmar A survey of symplectic $4$ 4 -manifolds with $b^{+}=1$ b^{+}=1 . Turkish J. Math. 20 (1996), no. 1, 47\u201360. (Reviewer: Paolo Lisca) 57R15 (57N13 57R57)',
#   'id': u'1392662',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1392662'},
#  {'date': -1,
#   'description': u'Robbin, Joel ; Salamon, Dietmar Feynman path integrals on phase space and the metaplectic representation. Math. Z. 221 (1996), no. 2, 307\u2013335. (Reviewer: Yu. E. Gliklikh (Zbl 848.58008)) 58D30 (58F06 81S10 81S40)',
#   'id': u'1376300',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1376300'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Lagrangian intersections, $3$ 3 -manifolds with boundary, and the Atiyah-Floer conjecture. Proceedings of the International Congress of Mathematicians, Vol. 1, 2 (Z\xfcrich, 1994), 526\u2013536, Birkh\xe4user, Basel, 1995. (Reviewer: Dave Auckly) 57R57 (55N35 57N10 57R15 58E05)',
#   'id': u'1403953',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1403953'},
#  {'date': -1,
#   'description': u'McDuff, Dusa ; Salamon, Dietmar Introduction to symplectic topology. Oxford Mathematical Monographs. Oxford Science Publications. The Clarendon Press, Oxford University Press, New York, 1995. viii+425 pp. ISBN: 0-19-851177-9 (Reviewer: Hansj\xf6rg Geiges) 58F05 (53C15 57R57 58E05)',
#   'id': u'1373431',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1373431'},
#  {'date': -1,
#   'description': u'Hofer, H. ; Salamon, D. A. Floer homology and Novikov rings. The Floer memorial volume, 483\u2013524, Progr. Math., 133, Birkh\xe4user, Basel, 1995. (Reviewer: Dave Auckly) 57R57 (55N35 58E05)',
#   'id': u'1362838',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1362838'},
#  {'date': -1,
#   'description': u'Floer, Andreas ; Hofer, Helmut ; Salamon, Dietmar Transversality in elliptic Morse theory for the symplectic action. Duke Math. J. 80 (1995), no. 1, 251\u2013292. (Reviewer: Karl Friedrich Siburg) 58E05 (57R70 58F05)',
#   'id': u'1360618',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1360618'},
#  {'date': -1,
#   'description': u'Eliashberg, Y. ; Hofer, H. ; Salamon, D. Lagrangian intersections in contact geometry. Geom. Funct. Anal. 5 (1995), no. 2, 244\u2013269. (Reviewer: Yong-Geun Oh) 58E05 (53C15 58F05)',
#   'id': u'1334868',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1334868'},
#  {'date': -1,
#   'description': u'Robbin, Joel ; Salamon, Dietmar The spectral flow and the Maslov index. Bull. London Math. Soc. 27 (1995), no. 1, 1\u201333. (Reviewer: James F. Reineck) 58E05 (47A53 47N99 57R57 58G10)',
#   'id': u'1331677',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1331677'},
#  {'date': -1,
#   'description': u'Dostoglou, Stamatis ; Salamon, Dietmar A. Cauchy-Riemann operators, self-duality, and the spectral flow. First European Congress of Mathematics, Vol. I (Paris, 1992), 511\u2013545, Progr. Math., 119, Birkh\xe4user, Basel, 1994. (Reviewer: Karl Friedrich Siburg) 58E05 (57R57 58D27 58G10)',
#   'id': u'1341835',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1341835'},
#  {'date': -1,
#   'description': u'McDuff, Dusa ; Salamon, Dietmar $J$ J -holomorphic curves and quantum cohomology. University Lecture Series, 6. American Mathematical Society, Providence, RI, 1994. viii+207 pp. ISBN: 0-8218-0332-8 (Reviewer: Bruce Hunt) 58D10 (14J32 32J17 53C42 57R57 58E12)',
#   'id': u'1286255',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1286255'},
#  {'date': -1,
#   'description': u'Dostoglou, Stamatis ; Salamon, Dietmar A. Self-dual instantons and holomorphic curves. Ann. of Math. (2) 139 (1994), no. 3, 581\u2013640. (Reviewer: S. Donaldson) 58E15 (53C07 57R57 58D15 58D27)',
#   'id': u'1283871',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1283871'},
#  {'date': -1,
#   'description': u'Robbin, Joel ; Salamon, Dietmar Phase functions and path integrals. Symplectic geometry, 203\u2013226, London Math. Soc. Lecture Note Ser., 192, Cambridge Univ. Press, Cambridge, 1993. (Reviewer: Karl Friedrich Siburg) 58F05 (58D30 58E05 58F06 81S10 81S40)',
#   'id': u'1297138',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1297138'},
#  {'date': -1,
#   'description': u'Dostoglou, Stamatis ; Salamon, Dietmar Instanton homology and symplectic fixed points. Symplectic geometry, 57\u201393, London Math. Soc. Lecture Note Ser., 192, Cambridge Univ. Press, Cambridge, 1993. (Reviewer: Dave Auckly) 58E15 (53C07 57R57 58D15 58D27)',
#   'id': u'1297130',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1297130'},
#  {'date': -1,
#   'description': u'Robbin, Joel ; Salamon, Dietmar The Maslov index for paths. Topology 32 (1993), no. 4, 827\u2013844. (Reviewer: J. S. Joel) 58F05 (58E05)',
#   'id': u'1241874',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1241874'},
#  {'date': -1,
#   'description': u'Dostoglou, Stamatis ; Salamon, Dietmar Floer homology for mapping cylinders. Mathematical physics, X (Leipzig, 1991), 269\u2013271, Springer, Berlin, 1992. 58E05 (55N22 57R57)',
#   'id': u'1386413',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1386413'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar ; Zehnder, Eduard Morse theory for periodic solutions of Hamiltonian systems and the Maslov index. Comm. Pure Appl. Math. 45 (1992), no. 10, 1303\u20131360. (Reviewer: Yong-Geun Oh) 58E05 (34C25 58F22 70H05)',
#   'id': u'1181727',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1181727'},
#  {'date': -1,
#   'description': u'Robbin, Joel W. ; Salamon, Dietmar A. Lyapunov maps, simplicial complexes and the Stone functor. Ergodic Theory Dynam. Systems 12 (1992), no. 1, 153\u2013183. (Reviewer: Christopher K. McCord) 58F12',
#   'id': u'1162405',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1162405'},
#  {'date': -1,
#   'description': u'Ito, Kazufumi ; Kappel, Franz ; Salamon, Dietmar A variational approach to approximation of delay systems. Differential Integral Equations 4 (1991), no. 1, 51\u201372. (Reviewer: Mats Gyllenberg) 47D03 (34K05 35R10 92D25)',
#   'id': u'1079610',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1079610'},
#  {'date': -1,
#   'description': u'Kappel, Franz ; Salamon, Dietmar An approximation theorem for the algebraic Riccati equation. SIAM J. Control Optim. 28 (1990), no. 5, 1136\u20131147. (Reviewer: A. Halanay) 93C25 (41A15 47A62 49N10 93B40)',
#   'id': u'1064722',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1064722'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Morse theory, the Conley index and Floer homology. Bull. London Math. Soc. 22 (1990), no. 2, 113\u2013140. (Reviewer: Jean-Claude Sikorav) 58E05 (55N99 57R70 58D15 58F05 58G20)',
#   'id': u'1045282',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1045282'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar ; Zehnder, Eduard Floer homology, the Maslov index and periodic orbits of Hamiltonian equations. Analysis, et cetera, 573\u2013600, Academic Press, Boston, MA, 1990. (Reviewer: Yong-Geun Oh) 58F05 (55N35 58E05 58F22 70H05)',
#   'id': u'1039363',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=1039363'},
#  {'date': -1,
#   'description': u'Colonius, Fritz ; Manitius, Andrzej ; Salamon, Dietmar Structure theory and duality for time varying retarded functional-differential equations. J. Differential Equations 78 (1989), no. 2, 320\u2013353. (Reviewer: V. \u0160eda) 34K05 (47H15)',
#   'id': u'0992150',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0992150'},
#  {'date': -1,
#   'description': u'Kappel, F. ; Salamon, D. On the stability properties of spline approximations for retarded systems. SIAM J. Control Optim. 27 (1989), no. 2, 407\u2013431. (Reviewer: Miko\u0142aj Bus\u0142owicz) 34K35 (34K20 41A15 65K10 93D15)',
#   'id': u'0984835',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0984835'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar ; Zehnder, Eduard KAM theory in configuration space. Comment. Math. Helv. 64 (1989), no. 1, 84\u2013132. (Reviewer: Jaroslav Stark) 58F05 (58E15 58F27 58F30 70H05)',
#   'id': u'0982563',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0982563'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Realization theory in Hilbert space. Math. Systems Theory 21 (1989), no. 3, 147\u2013164. 93B15 (47D05 93B28 93C25 93D25)',
#   'id': u'0977021',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0977021'},
#  {'date': -1,
#   'description': u'Robbin, Joel W. ; Salamon, Dietmar Dynamical systems, shape theory and the Conley index. Ergodic Theory Dynam. Systems 8$^*$ (1988), Charles Conley Memorial Issue, 375\u2013393. (Reviewer: Waldyr M. Oliva) 58F10 (55M25)',
#   'id': u'0967645',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0967645'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar ; Zehnder, Eduard Flows on vector bundles and hyperbolic sets. Trans. Amer. Math. Soc. 306 (1988), no. 2, 623\u2013649. (Reviewer: Dietrich Flockerzi) 58F15 (34C35)',
#   'id': u'0933310',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0933310'},
#  {'date': -1,
#   'description': u'Kappel, F. ; Salamon, D. Spline approximation for retarded systems and the Riccati equation. SIAM J. Control Optim. 25 (1987), no. 4, 1082\u20131117. (Reviewer: Teodor Hav\xe2rneanu) 34K35 (34G20 49A27 65K10)',
#   'id': u'0894000',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0894000'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Infinite-dimensional linear systems with unbounded control and observation: a functional analytic approach. Trans. Amer. Math. Soc. 300 (1987), no. 2, 383\u2013431. (Reviewer: R. F. Datko) 93C25 (34G10 47A99 47D05 49A27)',
#   'id': u'0876460',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0876460'},
#  {'date': -1,
#   'description': u'Pritchard, A. J. ; Salamon, D. The linear quadratic control problem for infinite-dimensional systems with unbounded input and output operators. SIAM J. Control Optim. 25 (1987), no. 1, 121\u2013144. (Reviewer: Jerzy Zabczyk) 93C25 (93C05 93C20)',
#   'id': u'0872455',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0872455'},
#  {'date': -1,
#   'description': u'Curtain, R. F. ; Salamon, D. Finite-dimensional compensators for infinite-dimensional systems with unbounded input operators. SIAM J. Control Optim. 24 (1986), no. 4, 797\u2013816. (Reviewer: Andrzej W. Olbrot) 93C25 (93D15)',
#   'id': u'0846384',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0846384'},
#  {'date': -1,
#   'description': u'Salamon, D. An abstract framework for infinite-dimensional systems with unbounded control and observation. Distributed parameter systems (Vorau, 1984), 324\u2013339, Lecture Notes in Control and Inform. Sci., 75, Springer, Berlin, 1985. 93B28 (93C20)',
#   'id': u'0897567',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0897567'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Structure and stability of finite-dimensional approximations for functional-differential equations. SIAM J. Control Optim. 23 (1985), no. 6, 928\u2013951. (Reviewer: Andrzej W. Olbrot) 34K15 (65L20)',
#   'id': u'0809542',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0809542'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Connected simple systems and the Conley index of isolated invariant sets. Trans. Amer. Math. Soc. 291 (1985), no. 1, 1\u201341. 58F25 (34C35)',
#   'id': u'0797044',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0797044'},
#  {'date': -1,
#   'description': u'Curtain, Ruth F. ; Salamon, Dietmar A note on the disturbance decoupling problem for retarded systems. Systems Control Lett. 5 (1985), no. 5, 335\u2013338. (Reviewer: Luciano Pandolfi) 34K35 (93C25)',
#   'id': u'0791549',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0791549'},
#  {'date': -1,
#   'description': u'Pritchard, A. J. ; Salamon, D. The linear quadratic optimal control problem for infinite-dimensional systems with unbounded input and output operators. Infinite-dimensional systems (Retzhof, 1983), 187\u2013202, Lecture Notes in Math., 1076, Springer, Berlin, 1984. 49A27 (93B99)',
#   'id': u'0763363',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0763363'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar On controllability and observability of time delay systems. IEEE Trans. Automat. Control 29 (1984), no. 5, 432\u2013439. (Reviewer: Ethelbert N. Chukwu) 93B05 (34K35 93B07)',
#   'id': u'0748207',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0748207'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Control and observation of neutral systems. Research Notes in Mathematics, 91. Pitman (Advanced Publishing Program), Boston, MA, 1984. vii+207 $pp.$ pp. . ISBN: 0-273-08618-9 (Reviewer: Andrzej Manitius) 93-02 (34H05 34K35 45E10 47A99 93B28)',
#   'id': u'0724934',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0724934'},
#  {'date': -1,
#   'description': u'Salamon, D. Dynamic observation and feedback stabilization for retarded systems with delays in input and output. Control of distributed parameter systems, 1982 (Toulouse, 1982), 631\u2013633, IFAC, Laxenburg, 1983. 93D15 (34K35)',
#   'id': u'0811272',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0811272'},
#  {'date': -1,
#   'description': u'Salamon, D. Neutral functional differential equations and semigroups of operators. Control theory for distributed parameter systems and applications (Vorau, 1982), 188\u2013207, Lecture Notes in Control and Inform. Sci., 54, Springer, Berlin, 1983. 34K35 (93B28)',
#   'id': u'0793045',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0793045'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar Observability of nontrivial small solutions for neutral systems. Systems Control Lett. 3 (1983), no. 2, 91\u201399. 93B07 (34K99)',
#   'id': u'0712127',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0712127'},
#  {'date': -1,
#   'description': u'Salamon, Dietmar A duality principle for neutral functional-differential equations. Equadiff 82 (W\xfcrzburg, 1982), 543\u2013552, Lecture Notes in Math., 1017, Springer, Berlin, 1983. (Reviewer: Andrzej W. Olbrot) 93C30 (34K35)',
#   'id': u'0726611',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0726611'},
#  {'date': -1,
#   'description': u'Salamon, D. On dynamic observations and state feedback for time delay systems. Evolution equations and their applications (Schloss Retzhof, 1981), pp. 202\u2013219, Res. Notes in Math., 68, Pitman, Boston, Mass.-London, 1982. (Reviewer: V. M. Marchenko) 93B07 (93D15)',
#   'id': u'0668388',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0668388'},
#  {'date': -1,
#   'description': u'Salamon, D. Observers and duality between observation and state feedback for time delay systems. IEEE Trans. Automat. Control 25 (1980), no. 6, 1187\u20131192. 93B07 (34K05 47D05 93C50)',
#   'id': u'0601503',
#   'url': u'http://www.ams.org/mathscinet/search/publdoc.html?pg1=MR&s1=0601503'}]
